# %%
import os
import fnmatch
import cv2
import numpy as np
import string
import time

from keras.preprocessing.sequence import pad_sequences

from keras.layers import Dense, LSTM, Reshape, BatchNormalization, Input, Conv2D, MaxPool2D, Lambda, Bidirectional
from keras.models import Model
from keras.activations import relu, sigmoid, softmax
import keras.backend as K
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
import tensorflow.compat.v1 as tf
from tensorflow.python.client import device_lib

#from google.colab import drive
#drive.mount('/content/drive')

tf.disable_v2_behavior()
tf.logging.set_verbosity(tf.logging.ERROR)

# Check all available devices if GPU is available
print(device_lib.list_local_devices())
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14900191499262262266
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14626652160
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2366681422775044046
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %%
char_list = string.ascii_letters+string.digits

def encode_to_labels(txt):
    dig_lst = []
    for index, char in enumerate(txt):
        try:
            dig_lst.append(char_list.index(char))
        except:
            print(char)

    return dig_lst

# %%
#import shutil

#shutil.unpack_archive("drive/My Drive/mjsynth.tar.gz", "/content/drive/My Drive/mjsynth_dataset")

# %%
# !pip install datasets
from datasets import load_dataset
import numpy as np
import cv2
from PIL import Image

#Load dataset from Hugging Face Hub
dataset = load_dataset('priyank-m/MJSynth_text_recognition', split='train')

#Process images
def process_image(pil_img):
    #Convert PIL Image to grayscale
    img = pil_img.convert('L')

    #Convert PIL Image to np array
    img = np.array(img)

    #Resize image to (32, 128) if larger
    w, h = img.shape
    if h > 128 or w > 32:
        img = cv2.resize(img, (128, 32), interpolation=cv2.INTER_AREA)
        w, h = img.shape  #Update dimensions

    #Add padding
    if w < 32 or h < 128:
        add_zeros_height = np.ones((32 - w, min(128, h))) * 255  # Pad height if needed
        add_zeros_width = np.ones((32, 128 - h)) * 255  # Pad width if needed

        img = np.concatenate((img, add_zeros_height), axis=0) if w < 32 else img
        img = np.concatenate((img, add_zeros_width), axis=1) if h < 128 else img

    #Normalize image
    img = img/255.0
    img = np.expand_dims(img, axis=2)
    return img

#Process/split dataset
training_img = []
training_txt = []
valid_img = []
valid_txt = []
train_input_length = []
train_label_length = []
valid_input_length = []
valid_label_length = []
orig_txt = []
valid_orig_txt = []
max_label_len = 0

for i, item in enumerate(dataset):
    #Process image
    img = process_image(item['image'])

    #Extract text
    txt = item['label']

    #Update maximum label length
    max_label_len = max(max_label_len, len(txt))

    #Split data into validation/training sets
    if i % 10 == 0:
        valid_orig_txt.append(txt)
        valid_img.append(img)
        valid_txt.append(encode_to_labels(txt))
        valid_label_length.append(len(txt))
        valid_input_length.append(31)
    else:
        orig_txt.append(txt)
        training_img.append(img)
        training_txt.append(encode_to_labels(txt))
        train_label_length.append(len(txt))
        train_input_length.append(31)

    #Limit # processed images
    if i == 499999:
        break

print(f"Processed {len(training_img)} training images and {len(valid_img)} validation images.")
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Resolving data files:   0%|          | 0/25 [00:00<?, ?it/s]
# Processed 450000 training images and 50000 validation images.

# %%
# pad each output label to maximum text length
train_padded_txt = pad_sequences(training_txt, maxlen=max_label_len, padding='post', value = len(char_list))
valid_padded_txt = pad_sequences(valid_txt, maxlen=max_label_len, padding='post', value = len(char_list))

print(train_padded_txt)
# Out:
# [[44 15  4 ... 62 62 62]
#  [ 0  2  2 ... 62 62 62]
#  [28 26 43 ... 62 62 62]
#  ...
#  [33  0  6 ... 62 62 62]
#  [18  0 13 ... 62 62 62]
#  [28  0  2 ... 62 62 62]]

# %%
print(np.shape(train_padded_txt))
# Out:
# (450000, 23)

# %%
def build_model():
  inputs = Input(shape=(32,128,1))

  conv_1 = Conv2D(64, (3,3), activation = 'relu', padding='same')(inputs)
  pool_1 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_1)

  conv_2 = Conv2D(128, (3,3), activation = 'relu', padding='same')(pool_1)
  pool_2 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_2)

  conv_3 = Conv2D(256, (3,3), activation = 'relu', padding='same')(pool_2)

  conv_4 = Conv2D(256, (3,3), activation = 'relu', padding='same')(conv_3)
  pool_4 = MaxPool2D(pool_size=(2, 1))(conv_4)

  conv_5 = Conv2D(512, (3,3), activation = 'relu', padding='same')(pool_4)
  batch_norm_5 = BatchNormalization()(conv_5)

  conv_6 = Conv2D(512, (3,3), activation = 'relu', padding='same')(batch_norm_5)
  batch_norm_6 = BatchNormalization()(conv_6)
  pool_6 = MaxPool2D(pool_size=(2, 1))(batch_norm_6)

  conv_7 = Conv2D(512, (2,2), activation = 'relu')(pool_6)

  squeezed = Lambda(lambda x: K.squeeze(x, 1))(conv_7)

  blstm_1 = Bidirectional(LSTM(128, return_sequences=True, dropout = 0.2))(squeezed)
  blstm_2 = Bidirectional(LSTM(128, return_sequences=True, dropout = 0.2))(blstm_1)

  outputs = Dense(len(char_list)+1, activation = 'softmax')(blstm_2)

  act_model = Model(inputs, outputs)
  return act_model, inputs, outputs

# %%
act_model, inputs, outputs = build_model()
act_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 128, 1)]      0
#
#  conv2d_7 (Conv2D)           (None, 32, 128, 64)       640
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 64, 64)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 64, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 32, 128)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 8, 32, 256)        295168
#
#  conv2d_10 (Conv2D)          (None, 8, 32, 256)        590080
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 32, 256)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 4, 32, 512)        1180160
#
#  batch_normalization_2 (Bat  (None, 4, 32, 512)        2048
#  chNormalization)
#
#  conv2d_12 (Conv2D)          (None, 4, 32, 512)        2359808
#
#  batch_normalization_3 (Bat  (None, 4, 32, 512)        2048
#  chNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 2, 32, 512)        0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 1, 31, 512)        1049088
#
#  lambda_1 (Lambda)           (None, 31, 512)           0
#
#  bidirectional_2 (Bidirecti  (None, 31, 256)           656384
#  onal)
#
#  bidirectional_3 (Bidirecti  (None, 31, 256)           394240
#  onal)
#
#  dense_1 (Dense)             (None, 31, 63)            16191
#
# =================================================================
# Total params: 6619711 (25.25 MB)
# Trainable params: 6617663 (25.24 MB)
# Non-trainable params: 2048 (8.00 KB)
# _________________________________________________________________

# %%
labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')

print(input_length)
print(label_length)

def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([outputs, labels, input_length, label_length])

model = Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out)
# Out:
# Tensor("input_length_1:0", shape=(?, 1), dtype=int64)
# Tensor("label_length_1:0", shape=(?, 1), dtype=int64)

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer = 'adam')

filepath="best_model.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
callbacks_list = [checkpoint]

# %%
training_img = np.array(training_img)
valid_img = np.array(valid_img)

train_input_length = np.array(train_input_length)
train_label_length = np.array(train_label_length)
valid_input_length = np.array(valid_input_length)
valid_label_length = np.array(valid_label_length)
print(train_input_length)
#print(training_img)
#print(valid_img)
# Out:
# [31 31 31 ... 31 31 31]

# %%
print(np.shape(train_input_length))
print(valid_label_length)
print(valid_input_length)
# Out:
# (450000,)
# [ 4  6  5 ...  9  5 11]
# [31 31 31 ... 31 31 31]

# %%
print(len(training_img))
print(len(training_txt))
print(len(train_input_length))
print(len(train_label_length))
# Out:
# 450000
# 450000
# 450000
# 450000

# %%
# !pip install ray
# !pip install -U "ray[tune]"
# !pip install ray[tune] bayesian-optimization
# !pip install scikit-optimize
# import ray
# from ray import tune
# from ray import train
# from ray.tune.schedulers import HyperBandScheduler
# from ray.tune.search.bayesopt import BayesOptSearch


#Grid search hyperparameter tuning

# batch_sizes = [64, 128, 256]
# epochs = [10, 20, 30, 40, 50]

# for batch_size in batch_sizes:
#   for epoch in epochs:
#     print("BATCH SIZE: ")
#     print(batch_size)
#     print("EPOCHS: ")
#     print(epoch)
#     model = Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out)
#     model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer = 'adam')
#     model.fit(x=[training_img, train_padded_txt, train_input_length, train_label_length], y=np.zeros(len(training_img)), batch_size=batch_size, epochs = epoch, validation_data = ([valid_img, valid_padded_txt, valid_input_length, valid_label_length], [np.zeros(len(valid_img))]), verbose = 1, callbacks = callbacks_list)

# %%
print(np.shape(training_img))
print(np.shape(train_padded_txt))
print(np.shape(train_input_length))
print(np.shape(train_label_length))
#print(train_label_length)
#print(training_img)


#OPTIMAL BATCH SIZE AND EPOCHS
batch_size = 64
epochs = 20
model.fit(x=[training_img, train_padded_txt, train_input_length, train_label_length], y=np.zeros(len(training_img)), batch_size=batch_size, epochs = epochs, validation_data = ([valid_img, valid_padded_txt, valid_input_length, valid_label_length], [np.zeros(len(valid_img))]), verbose = 1, callbacks = callbacks_list)
# Out:
# (450000, 32, 128, 1)
# (450000, 23)
# (450000,)
# (450000,)
# Train on 450000 samples, validate on 50000 samples
# Epoch 1/20
# 450000/450000 [==============================] - ETA: 0s - loss: 24.5289
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Epoch 1: val_loss improved from inf to 10.54279, saving model to best_model.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 450000/450000 [==============================] - 754s 2ms/sample - loss: 24.5289 - val_loss: 10.5428
# Epoch 2/20
# 450000/450000 [==============================] - ETA: 0s - loss: 6.1176
# Epoch 2: val_loss improved from 10.54279 to 6.65361, saving model to best_model.hdf5
# 450000/450000 [==============================] - 760s 2ms/sample - loss: 6.1176 - val_loss: 6.6536
# Epoch 3/20
# 450000/450000 [==============================] - ETA: 0s - loss: 4.1928
# Epoch 3: val_loss improved from 6.65361 to 3.69054, saving model to best_model.hdf5
# 450000/450000 [==============================] - 767s 2ms/sample - loss: 4.1928 - val_loss: 3.6905
# Epoch 4/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.7681
# Epoch 4: val_loss improved from 3.69054 to 3.51883, saving model to best_model.hdf5
# 450000/450000 [==============================] - 762s 2ms/sample - loss: 3.7681 - val_loss: 3.5188
# Epoch 5/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.4657
# Epoch 5: val_loss improved from 3.51883 to 3.31471, saving model to best_model.hdf5
# 450000/450000 [==============================] - 760s 2ms/sample - loss: 3.4657 - val_loss: 3.3147
# Epoch 6/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.3321
# Epoch 6: val_loss improved from 3.31471 to 3.21003, saving model to best_model.hdf5
# 450000/450000 [==============================] - 761s 2ms/sample - loss: 3.3321 - val_loss: 3.2100
# Epoch 7/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.2502
# Epoch 7: val_loss improved from 3.21003 to 3.14317, saving model to best_model.hdf5
# 450000/450000 [==============================] - 761s 2ms/sample - loss: 3.2502 - val_loss: 3.1432
# Epoch 8/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.2049
# Epoch 8: val_loss improved from 3.14317 to 3.08841, saving model to best_model.hdf5
# 450000/450000 [==============================] - 762s 2ms/sample - loss: 3.2049 - val_loss: 3.0884
# Epoch 9/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.1623
# Epoch 9: val_loss improved from 3.08841 to 2.99820, saving model to best_model.hdf5
# 450000/450000 [==============================] - 761s 2ms/sample - loss: 3.1623 - val_loss: 2.9982
# Epoch 10/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.1070
# Epoch 10: val_loss did not improve from 2.99820
# 450000/450000 [==============================] - 772s 2ms/sample - loss: 3.1070 - val_loss: 3.0308
# Epoch 11/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.0861
# Epoch 11: val_loss improved from 2.99820 to 2.98854, saving model to best_model.hdf5
# 450000/450000 [==============================] - 771s 2ms/sample - loss: 3.0861 - val_loss: 2.9885
# Epoch 12/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.0449
# Epoch 12: val_loss did not improve from 2.98854
# 450000/450000 [==============================] - 767s 2ms/sample - loss: 3.0449 - val_loss: 3.0464
# Epoch 13/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.0656
# Epoch 13: val_loss improved from 2.98854 to 2.96482, saving model to best_model.hdf5
# 450000/450000 [==============================] - 770s 2ms/sample - loss: 3.0656 - val_loss: 2.9648
# Epoch 14/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.0654
# Epoch 14: val_loss did not improve from 2.96482
# 450000/450000 [==============================] - 764s 2ms/sample - loss: 3.0654 - val_loss: 3.0344
# Epoch 15/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.0451
# Epoch 15: val_loss did not improve from 2.96482
# 450000/450000 [==============================] - 756s 2ms/sample - loss: 3.0451 - val_loss: 3.0247
# Epoch 16/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.0565
# Epoch 16: val_loss did not improve from 2.96482
# 450000/450000 [==============================] - 746s 2ms/sample - loss: 3.0565 - val_loss: 3.0329
# Epoch 17/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.0278
# Epoch 17: val_loss improved from 2.96482 to 2.96312, saving model to best_model.hdf5
# 450000/450000 [==============================] - 748s 2ms/sample - loss: 3.0278 - val_loss: 2.9631
# Epoch 18/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.0477
# Epoch 18: val_loss improved from 2.96312 to 2.94634, saving model to best_model.hdf5
# 450000/450000 [==============================] - 750s 2ms/sample - loss: 3.0477 - val_loss: 2.9463
# Epoch 19/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.0376
# Epoch 19: val_loss did not improve from 2.94634
# 450000/450000 [==============================] - 748s 2ms/sample - loss: 3.0376 - val_loss: 3.0503
# Epoch 20/20
# 450000/450000 [==============================] - ETA: 0s - loss: 3.0502
# Epoch 20: val_loss did not improve from 2.94634
# 450000/450000 [==============================] - 746s 2ms/sample - loss: 3.0502 - val_loss: 3.0182

# %%
# !pip install python-Levenshtein

from Levenshtein import distance

act_model.load_weights('crnn_18.hdf5')

#act_model.save('crnn_best.h5', save_format='h5')

distances = []
accuracy = []
accuracy_adjusted = []
correct = []
incorrect = []

prediction = act_model.predict(valid_img[:50000])
out = K.get_value(K.ctc_decode(prediction, input_length=np.ones(prediction.shape[0])*prediction.shape[1],
                         greedy=True)[0][0])

i = 0
for x in out:
    print("original_text =  ", valid_orig_txt[i])
    print("predicted text = ", end = '')
    word = ''
    for p in x:
        if int(p) != -1:
            print(char_list[int(p)], end = '')
            word = word + char_list[int(p)]
    print('\n')
    print("WORD: ")
    print(word)
    print()
    distances.append(distance(valid_orig_txt[i], word))
    tempDist = distance(valid_orig_txt[i], word)
    print(tempDist)
    if word == valid_orig_txt[i]:
      print("IDENTICAL")
      accuracy.append(1)
      accuracy_adjusted.append(1)
    else:
      print("NOT IDENTICAL")
      accuracy.append(0)
      accuracy_adjusted.append(1/tempDist)
      incorrect.append(word)
      correct.append(valid_orig_txt[i])
    i+=1

print("DISTANCE: ")
print(np.shape(distances))
print(np.mean(distances))
print("ACCURACY: ")
print(np.shape(accuracy))
print(np.mean(accuracy))
print("ACCURACY ADJUSTED: ")
print(np.shape(accuracy_adjusted))
print(np.mean(accuracy_adjusted))
print("CORRECT SHAPE: ")
print(np.shape(correct))
print("INCORRECT SHAPE: ")
print(np.shape(incorrect))
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 0
# IDENTICAL
# original_text =   Entirety
# predicted text = Entirety
#
# WORD:
# Entirety
#
# 0
# IDENTICAL
# original_text =   Pummels
# predicted text = Pammels
#
# WORD:
# Pammels
#
# 1
# NOT IDENTICAL
# original_text =   REFINANCING
# predicted text = REANANCING
#
# WORD:
# REANANCING
#
# 2
# NOT IDENTICAL
# original_text =   GESTAPO
# predicted text = GESTAPO
#
# WORD:
# GESTAPO
#
# 0
# IDENTICAL
# original_text =   Ck
# predicted text = Ck
#
# WORD:
# Ck
#
# 0
# IDENTICAL
# original_text =   GAMOW
# predicted text = CAMOW
#
# WORD:
# CAMOW
#
# 1
# NOT IDENTICAL
# original_text =   Pervasively
# predicted text = Pervasively
#
# WORD:
# Pervasively
#
# 0
# IDENTICAL
# original_text =   Bozo
# predicted text = Bozo
#
# WORD:
# Bozo
#
# 0
# IDENTICAL
# original_text =   TURMOIL
# predicted text = TURMOIL
#
# WORD:
# TURMOIL
#
# 0
# IDENTICAL
# original_text =   canniest
# predicted text = cannlest
#
# WORD:
# cannlest
#
# 1
# NOT IDENTICAL
# original_text =   Geeky
# predicted text = Geeky
#
# WORD:
# Geeky
#
# 0
# IDENTICAL
# original_text =   guess
# predicted text = guess
#
# WORD:
# guess
#
# 0
# IDENTICAL
# original_text =   Preachiest
# predicted text = preachiest
#
# WORD:
# preachiest
#
# 1
# NOT IDENTICAL
# original_text =   MONTHLY
# predicted text = MONTHLY
#
# WORD:
# MONTHLY
#
# 0
# IDENTICAL
# original_text =   confer
# predicted text = confer
#
# WORD:
# confer
#
# 0
# IDENTICAL
# original_text =   LEGISLATORS
# predicted text = HEDISLRADAT
#
# WORD:
# HEDISLRADAT
#
# 7
# NOT IDENTICAL
# original_text =   MITZI
# predicted text = MAtTS
#
# WORD:
# MAtTS
#
# 4
# NOT IDENTICAL
# original_text =   LEVY
# predicted text = LEVY
#
# WORD:
# LEVY
#
# 0
# IDENTICAL
# original_text =   QUICKENING
# predicted text = QUICKENING
#
# WORD:
# QUICKENING
#
# 0
# IDENTICAL
# original_text =   INIQUITIES
# predicted text = NQUITES
#
# WORD:
# NQUITES
#
# 3
# NOT IDENTICAL
# original_text =   TICKLISHLY
# predicted text = TICKLISHLY
#
# WORD:
# TICKLISHLY
#
# 0
# IDENTICAL
# original_text =   nike
# predicted text = nike
#
# WORD:
# nike
#
# 0
# IDENTICAL
# original_text =   authenticate
# predicted text = authenticate
#
# WORD:
# authenticate
#
# 0
# IDENTICAL
# original_text =   LEGISLATE
# predicted text = EGSLATE
#
# WORD:
# EGSLATE
#
# 2
# NOT IDENTICAL
# original_text =   SPELLBIND
# predicted text = SPELLBIND
#
# WORD:
# SPELLBIND
#
# 0
# IDENTICAL
# original_text =   unlivable
# predicted text = unlivable
#
# WORD:
# unlivable
#
# 0
# IDENTICAL
# original_text =   choicest
# predicted text = choicest
#
# WORD:
# choicest
#
# 0
# IDENTICAL
# original_text =   mystified
# predicted text = mystified
#
# WORD:
# mystified
#
# 0
# IDENTICAL
# original_text =   NEPHEWS
# predicted text = NEPHEWS
#
# WORD:
# NEPHEWS
#
# 0
# IDENTICAL
# original_text =   NOTIFICATION
# predicted text = NOTIFICATION
#
# WORD:
# NOTIFICATION
#
# 0
# IDENTICAL
# original_text =   brainpower
# predicted text = brainpower
#
# WORD:
# brainpower
#
# 0
# IDENTICAL
# original_text =   Prone
# predicted text = Prone
#
# WORD:
# Prone
#
# 0
# IDENTICAL
# original_text =   Description
# predicted text = Dsseribtion
#
# WORD:
# Dsseribtion
#
# 3
# NOT IDENTICAL
# original_text =   Squashes
# predicted text = Squashes
#
# WORD:
# Squashes
#
# 0
# IDENTICAL
# original_text =   dietetic
# predicted text = dietetic
#
# WORD:
# dietetic
#
# 0
# IDENTICAL
# original_text =   Heritage
# predicted text = Reritage
#
# WORD:
# Reritage
#
# 1
# NOT IDENTICAL
# original_text =   Delints
# predicted text = Delints
#
# WORD:
# Delints
#
# 0
# IDENTICAL
# original_text =   excavator
# predicted text = excavator
#
# WORD:
# excavator
#
# 0
# IDENTICAL
# original_text =   Smartening
# predicted text = Smartening
#
# WORD:
# Smartening
#
# 0
# IDENTICAL
# original_text =   shortwave
# predicted text = shortivabe
#
# WORD:
# shortivabe
#
# 3
# NOT IDENTICAL
# original_text =   Spillways
# predicted text = Spillways
#
# WORD:
# Spillways
#
# 0
# IDENTICAL
# original_text =   AUGUSTUS
# predicted text = AUGUSTUS
#
# WORD:
# AUGUSTUS
#
# 0
# IDENTICAL
# original_text =   Brighteners
# predicted text = Brighteners
#
# WORD:
# Brighteners
#
# 0
# IDENTICAL
# original_text =   LEERED
# predicted text = LEERED
#
# WORD:
# LEERED
#
# 0
# IDENTICAL
# original_text =   CLARIFIED
# predicted text = CLARIFIED
#
# WORD:
# CLARIFIED
#
# 0
# IDENTICAL
# original_text =   Lactic
# predicted text = Lactic
#
# WORD:
# Lactic
#
# 0
# IDENTICAL
# original_text =   ROCKETING
# predicted text = ROCKETING
#
# WORD:
# ROCKETING
#
# 0
# IDENTICAL
# original_text =   ritually
# predicted text = ritually
#
# WORD:
# ritually
#
# 0
# IDENTICAL
# original_text =   Amalgamate
# predicted text = Amalgamate
#
# WORD:
# Amalgamate
#
# 0
# IDENTICAL
# original_text =   IRREFUTABLY
# predicted text = RREFUTABLY
#
# WORD:
# RREFUTABLY
#
# 1
# NOT IDENTICAL
# original_text =   disbarred
# predicted text = disbarred
#
# WORD:
# disbarred
#
# 0
# IDENTICAL
# original_text =   VINDICATIONS
# predicted text = VINDICATIONS
#
# WORD:
# VINDICATIONS
#
# 0
# IDENTICAL
# original_text =   MINICABS
# predicted text = MINICABS
#
# WORD:
# MINICABS
#
# 0
# IDENTICAL
# original_text =   Archaist
# predicted text = Archaist
#
# WORD:
# Archaist
#
# 0
# IDENTICAL
# original_text =   ENPLANED
# predicted text = ssatnnns
#
# WORD:
# ssatnnns
#
# 8
# NOT IDENTICAL
# original_text =   shakier
# predicted text = shakier
#
# WORD:
# shakier
#
# 0
# IDENTICAL
# original_text =   bombardier
# predicted text = bombardier
#
# WORD:
# bombardier
#
# 0
# IDENTICAL
# original_text =   dank
# predicted text = dank
#
# WORD:
# dank
#
# 0
# IDENTICAL
# original_text =   oftener
# predicted text = oftener
#
# WORD:
# oftener
#
# 0
# IDENTICAL
# original_text =   moonlighting
# predicted text = noonlighting
#
# WORD:
# noonlighting
#
# 1
# NOT IDENTICAL
# original_text =   Godmothers
# predicted text = GODHOTHERS
#
# WORD:
# GODHOTHERS
#
# 9
# NOT IDENTICAL
# original_text =   Complementing
# predicted text = Complementing
#
# WORD:
# Complementing
#
# 0
# IDENTICAL
# original_text =   HARRUMPHS
# predicted text = HARRUMPHS
#
# WORD:
# HARRUMPHS
#
# 0
# IDENTICAL
# original_text =   Insipidity
# predicted text = Insipidity
#
# WORD:
# Insipidity
#
# 0
# IDENTICAL
# original_text =   Caravansaries
# predicted text = Caravansaries
#
# WORD:
# Caravansaries
#
# 0
# IDENTICAL
# original_text =   Janglers
# predicted text = danalers
#
# WORD:
# danalers
#
# 2
# NOT IDENTICAL
# original_text =   CONJ
# predicted text = COnJ
#
# WORD:
# COnJ
#
# 1
# NOT IDENTICAL
# original_text =   Musher
# predicted text = Wusker
#
# WORD:
# Wusker
#
# 2
# NOT IDENTICAL
# original_text =   oberlin
# predicted text = oberlin
#
# WORD:
# oberlin
#
# 0
# IDENTICAL
# original_text =   GUILTIEST
# predicted text = GUILTIEST
#
# WORD:
# GUILTIEST
#
# 0
# IDENTICAL
# original_text =   Sealer
# predicted text = Senler
#
# WORD:
# Senler
#
# 1
# NOT IDENTICAL
# original_text =   CALVES
# predicted text = CALVES
#
# WORD:
# CALVES
#
# 0
# IDENTICAL
# original_text =   PARETO
# predicted text = PARETO
#
# WORD:
# PARETO
#
# 0
# IDENTICAL
# original_text =   Eponymous
# predicted text = Eponymous
#
# WORD:
# Eponymous
#
# 0
# IDENTICAL
# original_text =   Executes
# predicted text = Executes
#
# WORD:
# Executes
#
# 0
# IDENTICAL
# original_text =   Philosophies
# predicted text = Pelicapies
#
# WORD:
# Pelicapies
#
# 6
# NOT IDENTICAL
# original_text =   POLYGLOT
# predicted text = POLYGLOT
#
# WORD:
# POLYGLOT
#
# 0
# IDENTICAL
# original_text =   Departure
# predicted text = Departure
#
# WORD:
# Departure
#
# 0
# IDENTICAL
# original_text =   cunningly
# predicted text = cunningly
#
# WORD:
# cunningly
#
# 0
# IDENTICAL
# original_text =   soliloquized
# predicted text = SOlLLOQUZED
#
# WORD:
# SOlLLOQUZED
#
# 11
# NOT IDENTICAL
# original_text =   SCRATCHED
# predicted text = SCRATCHED
#
# WORD:
# SCRATCHED
#
# 0
# IDENTICAL
# original_text =   Affiance
# predicted text = Affiance
#
# WORD:
# Affiance
#
# 0
# IDENTICAL
# original_text =   SPASM
# predicted text = SPASM
#
# WORD:
# SPASM
#
# 0
# IDENTICAL
# original_text =   bridgett
# predicted text = bridgett
#
# WORD:
# bridgett
#
# 0
# IDENTICAL
# original_text =   tangerines
# predicted text = tangerines
#
# WORD:
# tangerines
#
# 0
# IDENTICAL
# original_text =   Replays
# predicted text = Replayss
#
# WORD:
# Replayss
#
# 1
# NOT IDENTICAL
# original_text =   Guthikonda
# predicted text = Guthikonda
#
# WORD:
# Guthikonda
#
# 0
# IDENTICAL
# original_text =   niter
# predicted text = niter
#
# WORD:
# niter
#
# 0
# IDENTICAL
# original_text =   PIPITS
# predicted text = PIPITS
#
# WORD:
# PIPITS
#
# 0
# IDENTICAL
# original_text =   Damage
# predicted text = Damags
#
# WORD:
# Damags
#
# 1
# NOT IDENTICAL
# original_text =   scrummage
# predicted text = scrummage
#
# WORD:
# scrummage
#
# 0
# IDENTICAL
# original_text =   SELFLESSNESS
# predicted text = SELFLESSNESS
#
# WORD:
# SELFLESSNESS
#
# 0
# IDENTICAL
# original_text =   Hungered
# predicted text = Hungered
#
# WORD:
# Hungered
#
# 0
# IDENTICAL
# original_text =   ASSIGNMENTS
# predicted text = ASSIGNMENTS
#
# WORD:
# ASSIGNMENTS
#
# 0
# IDENTICAL
# original_text =   activities
# predicted text = activities
#
# WORD:
# activities
#
# 0
# IDENTICAL
# original_text =   depressed
# predicted text = depressed
#
# WORD:
# depressed
#
# 0
# IDENTICAL
# original_text =   interception
# predicted text = interception
#
# WORD:
# interception
#
# 0
# IDENTICAL
# original_text =   descriptors
# predicted text = decaipions
#
# WORD:
# decaipions
#
# 4
# NOT IDENTICAL
# original_text =   Allegation
# predicted text = Mitatatier
#
# WORD:
# Mitatatier
#
# 7
# NOT IDENTICAL
# original_text =   Penitents
# predicted text = Penitents
#
# WORD:
# Penitents
#
# 0
# IDENTICAL
# original_text =   Paymasters
# predicted text = Paymasters
#
# WORD:
# Paymasters
#
# 0
# IDENTICAL
# original_text =   CREASED
# predicted text = CREASED
#
# WORD:
# CREASED
#
# 0
# IDENTICAL
# original_text =   Funnies
# predicted text = Funnies
#
# WORD:
# Funnies
#
# 0
# IDENTICAL
# original_text =   Thrashes
# predicted text = Thrashes
#
# WORD:
# Thrashes
#
# 0
# IDENTICAL
# original_text =   NARKY
# predicted text = NARKY
#
# WORD:
# NARKY
#
# 0
# IDENTICAL
# original_text =   unhardened
# predicted text = unhardened
#
# WORD:
# unhardened
#
# 0
# IDENTICAL
# original_text =   meddler
# predicted text = MEDDLER
#
# WORD:
# MEDDLER
#
# 7
# NOT IDENTICAL
# original_text =   Rousing
# predicted text = Rousing
#
# WORD:
# Rousing
#
# 0
# IDENTICAL
# original_text =   Agog
# predicted text = Agsg
#
# WORD:
# Agsg
#
# 1
# NOT IDENTICAL
# original_text =   RECONSIGNING
# predicted text = RECOMSIGYING
#
# WORD:
# RECOMSIGYING
#
# 2
# NOT IDENTICAL
# original_text =   prizefighters
# predicted text = Aeafes
#
# WORD:
# Aeafes
#
# 10
# NOT IDENTICAL
# original_text =   Peafowl
# predicted text = Peafowl
#
# WORD:
# Peafowl
#
# 0
# IDENTICAL
# original_text =   Valedictorians
# predicted text = Valedictorians
#
# WORD:
# Valedictorians
#
# 0
# IDENTICAL
# original_text =   Appraise
# predicted text = Appraise
#
# WORD:
# Appraise
#
# 0
# IDENTICAL
# original_text =   heeled
# predicted text = heeled
#
# WORD:
# heeled
#
# 0
# IDENTICAL
# original_text =   EXTRAPOLATE
# predicted text = BXTRAPOLATE
#
# WORD:
# BXTRAPOLATE
#
# 1
# NOT IDENTICAL
# original_text =   galaxy
# predicted text = galaxy
#
# WORD:
# galaxy
#
# 0
# IDENTICAL
# original_text =   ZUM
# predicted text = ZUM
#
# WORD:
# ZUM
#
# 0
# IDENTICAL
# original_text =   FETCHED
# predicted text = FETCHED
#
# WORD:
# FETCHED
#
# 0
# IDENTICAL
# original_text =   DUFF
# predicted text = DUEE
#
# WORD:
# DUEE
#
# 2
# NOT IDENTICAL
# original_text =   stalemating
# predicted text = stalemating
#
# WORD:
# stalemating
#
# 0
# IDENTICAL
# original_text =   landmasses
# predicted text = landmasses
#
# WORD:
# landmasses
#
# 0
# IDENTICAL
# original_text =   Abundance
# predicted text = Abundonce
#
# WORD:
# Abundonce
#
# 1
# NOT IDENTICAL
# original_text =   thespians
# predicted text = thespians
#
# WORD:
# thespians
#
# 0
# IDENTICAL
# original_text =   Steamers
# predicted text = Steamus
#
# WORD:
# Steamus
#
# 2
# NOT IDENTICAL
# original_text =   Mainframe
# predicted text = Mainframe
#
# WORD:
# Mainframe
#
# 0
# IDENTICAL
# original_text =   Timelier
# predicted text = Timelier
#
# WORD:
# Timelier
#
# 0
# IDENTICAL
# original_text =   hewing
# predicted text = hewing
#
# WORD:
# hewing
#
# 0
# IDENTICAL
# original_text =   breach
# predicted text = breach
#
# WORD:
# breach
#
# 0
# IDENTICAL
# original_text =   Crab
# predicted text = Crab
#
# WORD:
# Crab
#
# 0
# IDENTICAL
# original_text =   Sailing
# predicted text = Sailing
#
# WORD:
# Sailing
#
# 0
# IDENTICAL
# original_text =   Firmwares
# predicted text = Fiumwanes
#
# WORD:
# Fiumwanes
#
# 2
# NOT IDENTICAL
# original_text =   ALEHOUSES
# predicted text = BLEHOUSES
#
# WORD:
# BLEHOUSES
#
# 1
# NOT IDENTICAL
# original_text =   TRANSCENDENCE
# predicted text = TRANSCENDENCE
#
# WORD:
# TRANSCENDENCE
#
# 0
# IDENTICAL
# original_text =   SCORCH
# predicted text = SCORCH
#
# WORD:
# SCORCH
#
# 0
# IDENTICAL
# original_text =   Cogitation
# predicted text = Cogitation
#
# WORD:
# Cogitation
#
# 0
# IDENTICAL
# original_text =   datebooks
# predicted text = datebooks
#
# WORD:
# datebooks
#
# 0
# IDENTICAL
# original_text =   DISCERNIBLE
# predicted text = DSCERMBlE
#
# WORD:
# DSCERMBlE
#
# 4
# NOT IDENTICAL
# original_text =   MORALIST
# predicted text = MORAIST
#
# WORD:
# MORAIST
#
# 1
# NOT IDENTICAL
# original_text =   BUTTY
# predicted text = BUTTY
#
# WORD:
# BUTTY
#
# 0
# IDENTICAL
# original_text =   BEEFY
# predicted text = BEEFY
#
# WORD:
# BEEFY
#
# 0
# IDENTICAL
# original_text =   Inadvisability
# predicted text = Inadvisabilily
#
# WORD:
# Inadvisabilily
#
# 1
# NOT IDENTICAL
# original_text =   moet
# predicted text = moct
#
# WORD:
# moct
#
# 1
# NOT IDENTICAL
# original_text =   piddly
# predicted text = piddly
#
# WORD:
# piddly
#
# 0
# IDENTICAL
# original_text =   Nightwatchmen
# predicted text = Nightwatenmen
#
# WORD:
# Nightwatenmen
#
# 2
# NOT IDENTICAL
# original_text =   UNQUOTE
# predicted text = UNQUOTE
#
# WORD:
# UNQUOTE
#
# 0
# IDENTICAL
# original_text =   solemnest
# predicted text = solemnest
#
# WORD:
# solemnest
#
# 0
# IDENTICAL
# original_text =   Staid
# predicted text = Staid
#
# WORD:
# Staid
#
# 0
# IDENTICAL
# original_text =   phys
# predicted text = phys
#
# WORD:
# phys
#
# 0
# IDENTICAL
# original_text =   LITIGATORS
# predicted text = LITIGHTORS
#
# WORD:
# LITIGHTORS
#
# 1
# NOT IDENTICAL
# original_text =   Cheyenne
# predicted text = Cheyenne
#
# WORD:
# Cheyenne
#
# 0
# IDENTICAL
# original_text =   Hotfoots
# predicted text = Hotfoots
#
# WORD:
# Hotfoots
#
# 0
# IDENTICAL
# original_text =   Yerevan
# predicted text = Yerevar
#
# WORD:
# Yerevar
#
# 1
# NOT IDENTICAL
# original_text =   WOMBS
# predicted text = WOMBS
#
# WORD:
# WOMBS
#
# 0
# IDENTICAL
# original_text =   Harasser
# predicted text = Harasser
#
# WORD:
# Harasser
#
# 0
# IDENTICAL
# original_text =   PURSUING
# predicted text = PURSUING
#
# WORD:
# PURSUING
#
# 0
# IDENTICAL
# original_text =   fetuses
# predicted text = fetuses
#
# WORD:
# fetuses
#
# 0
# IDENTICAL
# original_text =   flaws
# predicted text = flaws
#
# WORD:
# flaws
#
# 0
# IDENTICAL
# original_text =   Sullener
# predicted text = SUlETeS
#
# WORD:
# SUlETeS
#
# 5
# NOT IDENTICAL
# original_text =   Shinbones
# predicted text = Shinbones
#
# WORD:
# Shinbones
#
# 0
# IDENTICAL
# original_text =   SCARCITIES
# predicted text = SCARCITIES
#
# WORD:
# SCARCITIES
#
# 0
# IDENTICAL
# original_text =   MOHOROVICIC
# predicted text = MOHOROVICC
#
# WORD:
# MOHOROVICC
#
# 1
# NOT IDENTICAL
# original_text =   dorsally
# predicted text = dorsally
#
# WORD:
# dorsally
#
# 0
# IDENTICAL
# original_text =   REFRIGERATOR
# predicted text = BEPHIGERATOR
#
# WORD:
# BEPHIGERATOR
#
# 3
# NOT IDENTICAL
# original_text =   observing
# predicted text = observing
#
# WORD:
# observing
#
# 0
# IDENTICAL
# original_text =   shopkeepers
# predicted text = shopkeepers
#
# WORD:
# shopkeepers
#
# 0
# IDENTICAL
# original_text =   Emanation
# predicted text = Emanation
#
# WORD:
# Emanation
#
# 0
# IDENTICAL
# original_text =   BAKERS
# predicted text = BAKERS
#
# WORD:
# BAKERS
#
# 0
# IDENTICAL
# original_text =   Truthfulness
# predicted text = Truthfulness
#
# WORD:
# Truthfulness
#
# 0
# IDENTICAL
# original_text =   scree
# predicted text = scree
#
# WORD:
# scree
#
# 0
# IDENTICAL
# original_text =   wretchedly
# predicted text = inredelhcsly
#
# WORD:
# inredelhcsly
#
# 7
# NOT IDENTICAL
# original_text =   Buttonholed
# predicted text = Buttonholed
#
# WORD:
# Buttonholed
#
# 0
# IDENTICAL
# original_text =   jumpier
# predicted text = Largler
#
# WORD:
# Largler
#
# 5
# NOT IDENTICAL
# original_text =   Teargas
# predicted text = Teargas
#
# WORD:
# Teargas
#
# 0
# IDENTICAL
# original_text =   Gunmen
# predicted text = Cunmen
#
# WORD:
# Cunmen
#
# 1
# NOT IDENTICAL
# original_text =   TENDERLOINS
# predicted text = TENDERLOINS
#
# WORD:
# TENDERLOINS
#
# 0
# IDENTICAL
# original_text =   Misjudgment
# predicted text = Misjudgment
#
# WORD:
# Misjudgment
#
# 0
# IDENTICAL
# original_text =   IDENTIKIT
# predicted text = IDENTIXT
#
# WORD:
# IDENTIXT
#
# 2
# NOT IDENTICAL
# original_text =   SAPPERS
# predicted text = SAPPERS
#
# WORD:
# SAPPERS
#
# 0
# IDENTICAL
# original_text =   Brothel
# predicted text = Brathel
#
# WORD:
# Brathel
#
# 1
# NOT IDENTICAL
# original_text =   cranking
# predicted text = GRANKING
#
# WORD:
# GRANKING
#
# 8
# NOT IDENTICAL
# original_text =   Boggled
# predicted text = Boggled
#
# WORD:
# Boggled
#
# 0
# IDENTICAL
# original_text =   BADLY
# predicted text = BADLY
#
# WORD:
# BADLY
#
# 0
# IDENTICAL
# original_text =   Viler
# predicted text = Vilert
#
# WORD:
# Vilert
#
# 1
# NOT IDENTICAL
# original_text =   Wreathes
# predicted text = Wsathes
#
# WORD:
# Wsathes
#
# 2
# NOT IDENTICAL
# original_text =   deerstalker
# predicted text = deerstalker
#
# WORD:
# deerstalker
#
# 0
# IDENTICAL
# original_text =   MONOTONY
# predicted text = MONOTOTY
#
# WORD:
# MONOTOTY
#
# 1
# NOT IDENTICAL
# original_text =   BLOODS
# predicted text = BLOUDS
#
# WORD:
# BLOUDS
#
# 1
# NOT IDENTICAL
# original_text =   flyaway
# predicted text = flyaway
#
# WORD:
# flyaway
#
# 0
# IDENTICAL
# original_text =   Snorters
# predicted text = Snorters
#
# WORD:
# Snorters
#
# 0
# IDENTICAL
# original_text =   Tangoing
# predicted text = rangoing
#
# WORD:
# rangoing
#
# 1
# NOT IDENTICAL
# original_text =   cardiopulmonary
# predicted text = cardiopulmonary
#
# WORD:
# cardiopulmonary
#
# 0
# IDENTICAL
# original_text =   chippendale
# predicted text = chippendale
#
# WORD:
# chippendale
#
# 0
# IDENTICAL
# original_text =   Dibbled
# predicted text = Dibbled
#
# WORD:
# Dibbled
#
# 0
# IDENTICAL
# original_text =   RESPECTS
# predicted text = RESPECTS
#
# WORD:
# RESPECTS
#
# 0
# IDENTICAL
# original_text =   SECLUDE
# predicted text = SECLUDE
#
# WORD:
# SECLUDE
#
# 0
# IDENTICAL
# original_text =   dishonoring
# predicted text = dishonoring
#
# WORD:
# dishonoring
#
# 0
# IDENTICAL
# original_text =   REVILEMENT
# predicted text = REVILEMENT
#
# WORD:
# REVILEMENT
#
# 0
# IDENTICAL
# original_text =   Developed
# predicted text = Developed
#
# WORD:
# Developed
#
# 0
# IDENTICAL
# original_text =   Officious
# predicted text = Officious
#
# WORD:
# Officious
#
# 0
# IDENTICAL
# original_text =   detectives
# predicted text = detectives
#
# WORD:
# detectives
#
# 0
# IDENTICAL
# original_text =   OVERKILL
# predicted text = OVERKILL
#
# WORD:
# OVERKILL
#
# 0
# IDENTICAL
# original_text =   fishes
# predicted text = fishes
#
# WORD:
# fishes
#
# 0
# IDENTICAL
# original_text =   tickling
# predicted text = tickling
#
# WORD:
# tickling
#
# 0
# IDENTICAL
# original_text =   CARROTS
# predicted text = CARROTS
#
# WORD:
# CARROTS
#
# 0
# IDENTICAL
# original_text =   postindustrial
# predicted text = postindustrial
#
# WORD:
# postindustrial
#
# 0
# IDENTICAL
# original_text =   gigglers
# predicted text = gigglers
#
# WORD:
# gigglers
#
# 0
# IDENTICAL
# original_text =   rapider
# predicted text = rapider
#
# WORD:
# rapider
#
# 0
# IDENTICAL
# original_text =   Pampering
# predicted text = Pampering
#
# WORD:
# Pampering
#
# 0
# IDENTICAL
# original_text =   transepts
# predicted text = transepts
#
# WORD:
# transepts
#
# 0
# IDENTICAL
# original_text =   Dynamical
# predicted text = Dynamical
#
# WORD:
# Dynamical
#
# 0
# IDENTICAL
# original_text =   Translucency
# predicted text = Translucenty
#
# WORD:
# Translucenty
#
# 1
# NOT IDENTICAL
# original_text =   naught
# predicted text = naught
#
# WORD:
# naught
#
# 0
# IDENTICAL
# original_text =   HEADACHE
# predicted text = FENDACHE
#
# WORD:
# FENDACHE
#
# 2
# NOT IDENTICAL
# original_text =   pubescence
# predicted text = pubescence
#
# WORD:
# pubescence
#
# 0
# IDENTICAL
# original_text =   Augmentations
# predicted text = Rugmentations
#
# WORD:
# Rugmentations
#
# 1
# NOT IDENTICAL
# original_text =   POSTBANK
# predicted text = POSTBANK
#
# WORD:
# POSTBANK
#
# 0
# IDENTICAL
# original_text =   cosigns
# predicted text = cosigns
#
# WORD:
# cosigns
#
# 0
# IDENTICAL
# original_text =   Scammed
# predicted text = Scammed
#
# WORD:
# Scammed
#
# 0
# IDENTICAL
# original_text =   deodorizing
# predicted text = deodorizing
#
# WORD:
# deodorizing
#
# 0
# IDENTICAL
# original_text =   SHIPWRECKING
# predicted text = SHPWRECKING
#
# WORD:
# SHPWRECKING
#
# 1
# NOT IDENTICAL
# original_text =   TYPIFICATION
# predicted text = TYPIFICATION
#
# WORD:
# TYPIFICATION
#
# 0
# IDENTICAL
# original_text =   Sheeting
# predicted text = Sheeting
#
# WORD:
# Sheeting
#
# 0
# IDENTICAL
# original_text =   DISMAYING
# predicted text = DISHAYING
#
# WORD:
# DISHAYING
#
# 1
# NOT IDENTICAL
# original_text =   DISUSING
# predicted text = DISUSING
#
# WORD:
# DISUSING
#
# 0
# IDENTICAL
# original_text =   Boundlessness
# predicted text = Boundessness
#
# WORD:
# Boundessness
#
# 1
# NOT IDENTICAL
# original_text =   CANOODLED
# predicted text = CANOODLED
#
# WORD:
# CANOODLED
#
# 0
# IDENTICAL
# original_text =   Conglomerated
# predicted text = Cnodomerated
#
# WORD:
# Cnodomerated
#
# 3
# NOT IDENTICAL
# original_text =   ascetic
# predicted text = ascetic
#
# WORD:
# ascetic
#
# 0
# IDENTICAL
# original_text =   belays
# predicted text = belays
#
# WORD:
# belays
#
# 0
# IDENTICAL
# original_text =   epees
# predicted text = epees
#
# WORD:
# epees
#
# 0
# IDENTICAL
# original_text =   cains
# predicted text = cains
#
# WORD:
# cains
#
# 0
# IDENTICAL
# original_text =   Orgasm
# predicted text = Orgasm
#
# WORD:
# Orgasm
#
# 0
# IDENTICAL
# original_text =   COCHLEAE
# predicted text = GocHLeAe
#
# WORD:
# GocHLeAe
#
# 5
# NOT IDENTICAL
# original_text =   alongshore
# predicted text = alongshore
#
# WORD:
# alongshore
#
# 0
# IDENTICAL
# original_text =   CYBELE
# predicted text = CYBELE
#
# WORD:
# CYBELE
#
# 0
# IDENTICAL
# original_text =   Forelimbs
# predicted text = Forelimbs
#
# WORD:
# Forelimbs
#
# 0
# IDENTICAL
# original_text =   conversions
# predicted text = ionvrersitons
#
# WORD:
# ionvrersitons
#
# 3
# NOT IDENTICAL
# original_text =   EDIFYING
# predicted text = EDIFYING
#
# WORD:
# EDIFYING
#
# 0
# IDENTICAL
# original_text =   prussian
# predicted text = prussisn
#
# WORD:
# prussisn
#
# 1
# NOT IDENTICAL
# original_text =   miracle
# predicted text = miracle
#
# WORD:
# miracle
#
# 0
# IDENTICAL
# original_text =   Imperious
# predicted text = imperious
#
# WORD:
# imperious
#
# 1
# NOT IDENTICAL
# original_text =   orofino
# predicted text = orofino
#
# WORD:
# orofino
#
# 0
# IDENTICAL
# original_text =   birdhouse
# predicted text = birdhouse
#
# WORD:
# birdhouse
#
# 0
# IDENTICAL
# original_text =   wc
# predicted text = Wc
#
# WORD:
# Wc
#
# 1
# NOT IDENTICAL
# original_text =   GENTRIFICATION
# predicted text = GENTRIFICATION
#
# WORD:
# GENTRIFICATION
#
# 0
# IDENTICAL
# original_text =   MAYORESS
# predicted text = MAYORESS
#
# WORD:
# MAYORESS
#
# 0
# IDENTICAL
# original_text =   paramountcy
# predicted text = paramouwntcy
#
# WORD:
# paramouwntcy
#
# 1
# NOT IDENTICAL
# original_text =   alloyed
# predicted text = alloyed
#
# WORD:
# alloyed
#
# 0
# IDENTICAL
# original_text =   Condensers
# predicted text = Condemsers
#
# WORD:
# Condemsers
#
# 1
# NOT IDENTICAL
# original_text =   UNSHACKLE
# predicted text = WHSHICKLS
#
# WORD:
# WHSHICKLS
#
# 4
# NOT IDENTICAL
# original_text =   UMBER
# predicted text = UMBER
#
# WORD:
# UMBER
#
# 0
# IDENTICAL
# original_text =   FUTILELY
# predicted text = FUTILELY
#
# WORD:
# FUTILELY
#
# 0
# IDENTICAL
# original_text =   someplace
# predicted text = someplace
#
# WORD:
# someplace
#
# 0
# IDENTICAL
# original_text =   OUTDID
# predicted text = OUTDID
#
# WORD:
# OUTDID
#
# 0
# IDENTICAL
# original_text =   LOUD
# predicted text = BDUD
#
# WORD:
# BDUD
#
# 2
# NOT IDENTICAL
# original_text =   Gulches
# predicted text = Eulskes
#
# WORD:
# Eulskes
#
# 3
# NOT IDENTICAL
# original_text =   Subsequently
# predicted text = Subsegvantly
#
# WORD:
# Subsegvantly
#
# 3
# NOT IDENTICAL
# original_text =   CLXII
# predicted text = CLXI
#
# WORD:
# CLXI
#
# 1
# NOT IDENTICAL
# original_text =   Gritter
# predicted text = Gritter
#
# WORD:
# Gritter
#
# 0
# IDENTICAL
# original_text =   lavisher
# predicted text = lavisher
#
# WORD:
# lavisher
#
# 0
# IDENTICAL
# original_text =   MISMANAGEMENT
# predicted text = MISMANAGEVENT
#
# WORD:
# MISMANAGEVENT
#
# 1
# NOT IDENTICAL
# original_text =   PHILOSOPHIZES
# predicted text = PHICOSOPHIZES
#
# WORD:
# PHICOSOPHIZES
#
# 1
# NOT IDENTICAL
# original_text =   rothschild
# predicted text = rtschuid
#
# WORD:
# rtschuid
#
# 4
# NOT IDENTICAL
# original_text =   TIPSTERS
# predicted text = TIPSTERS
#
# WORD:
# TIPSTERS
#
# 0
# IDENTICAL
# original_text =   MCGUIRE
# predicted text = MCGUIRE
#
# WORD:
# MCGUIRE
#
# 0
# IDENTICAL
# original_text =   MOZAMBICAN
# predicted text = MOZAMBICAN
#
# WORD:
# MOZAMBICAN
#
# 0
# IDENTICAL
# original_text =   FUSIONS
# predicted text = FUsIONS
#
# WORD:
# FUsIONS
#
# 1
# NOT IDENTICAL
# original_text =   antoni
# predicted text = antoni
#
# WORD:
# antoni
#
# 0
# IDENTICAL
# original_text =   Bursar
# predicted text = Burran
#
# WORD:
# Burran
#
# 2
# NOT IDENTICAL
# original_text =   CHESTER
# predicted text = CHESTER
#
# WORD:
# CHESTER
#
# 0
# IDENTICAL
# original_text =   HECKLED
# predicted text = HECKLED
#
# WORD:
# HECKLED
#
# 0
# IDENTICAL
# original_text =   frontbenchers
# predicted text = trontbenchers
#
# WORD:
# trontbenchers
#
# 1
# NOT IDENTICAL
# original_text =   Francium
# predicted text = Francium
#
# WORD:
# Francium
#
# 0
# IDENTICAL
# original_text =   pogroms
# predicted text = pogroms
#
# WORD:
# pogroms
#
# 0
# IDENTICAL
# original_text =   Reflate
# predicted text = Reflate
#
# WORD:
# Reflate
#
# 0
# IDENTICAL
# original_text =   protozoan
# predicted text = protozoan
#
# WORD:
# protozoan
#
# 0
# IDENTICAL
# original_text =   Tomsk
# predicted text = Tomsh
#
# WORD:
# Tomsh
#
# 1
# NOT IDENTICAL
# original_text =   giles
# predicted text = giles
#
# WORD:
# giles
#
# 0
# IDENTICAL
# original_text =   GRADUALNESS
# predicted text = CRLDUALNESS
#
# WORD:
# CRLDUALNESS
#
# 2
# NOT IDENTICAL
# original_text =   ARTFULLY
# predicted text = ARFFULLY
#
# WORD:
# ARFFULLY
#
# 1
# NOT IDENTICAL
# original_text =   Awhile
# predicted text = Awhile
#
# WORD:
# Awhile
#
# 0
# IDENTICAL
# original_text =   ruthlessness
# predicted text = rathicarness
#
# WORD:
# rathicarness
#
# 5
# NOT IDENTICAL
# original_text =   STUBBIER
# predicted text = STUBBIER
#
# WORD:
# STUBBIER
#
# 0
# IDENTICAL
# original_text =   Unencumbered
# predicted text = Uneacumbered
#
# WORD:
# Uneacumbered
#
# 1
# NOT IDENTICAL
# original_text =   Outnumbered
# predicted text = Outnumbered
#
# WORD:
# Outnumbered
#
# 0
# IDENTICAL
# original_text =   efficiently
# predicted text = efficiently
#
# WORD:
# efficiently
#
# 0
# IDENTICAL
# original_text =   LARS
# predicted text = LARS
#
# WORD:
# LARS
#
# 0
# IDENTICAL
# original_text =   DAEMON
# predicted text = DAEMON
#
# WORD:
# DAEMON
#
# 0
# IDENTICAL
# original_text =   JAWBREAKER
# predicted text = JAWBREARES
#
# WORD:
# JAWBREARES
#
# 2
# NOT IDENTICAL
# original_text =   THERMOMETRIC
# predicted text = PRETUATLG
#
# WORD:
# PRETUATLG
#
# 10
# NOT IDENTICAL
# original_text =   repleting
# predicted text = repleting
#
# WORD:
# repleting
#
# 0
# IDENTICAL
# original_text =   minsk
# predicted text = minsk
#
# WORD:
# minsk
#
# 0
# IDENTICAL
# original_text =   UZBEK
# predicted text = UZBEK
#
# WORD:
# UZBEK
#
# 0
# IDENTICAL
# original_text =   Contracting
# predicted text = Contracting
#
# WORD:
# Contracting
#
# 0
# IDENTICAL
# original_text =   BLEACH
# predicted text = BLEACH
#
# WORD:
# BLEACH
#
# 0
# IDENTICAL
# original_text =   bioscience
# predicted text = bioscience
#
# WORD:
# bioscience
#
# 0
# IDENTICAL
# original_text =   Recolonize
# predicted text = Recolonize
#
# WORD:
# Recolonize
#
# 0
# IDENTICAL
# original_text =   INKING
# predicted text = INKING
#
# WORD:
# INKING
#
# 0
# IDENTICAL
# original_text =   PURIMS
# predicted text = PURIMS
#
# WORD:
# PURIMS
#
# 0
# IDENTICAL
# original_text =   Styrofoams
# predicted text = Styrofcons
#
# WORD:
# Styrofcons
#
# 3
# NOT IDENTICAL
# original_text =   patent
# predicted text = patent
#
# WORD:
# patent
#
# 0
# IDENTICAL
# original_text =   35th
# predicted text = 35th
#
# WORD:
# 35th
#
# 0
# IDENTICAL
# original_text =   Incinerating
# predicted text = Incinerating
#
# WORD:
# Incinerating
#
# 0
# IDENTICAL
# original_text =   DISREGARDED
# predicted text = BEPERAIED
#
# WORD:
# BEPERAIED
#
# 7
# NOT IDENTICAL
# original_text =   Sidebar
# predicted text = SOTELLS
#
# WORD:
# SOTELLS
#
# 6
# NOT IDENTICAL
# original_text =   neighborliness
# predicted text = meighborincss
#
# WORD:
# meighborincss
#
# 3
# NOT IDENTICAL
# original_text =   husks
# predicted text = husks
#
# WORD:
# husks
#
# 0
# IDENTICAL
# original_text =   Expectancy
# predicted text = Expectancy
#
# WORD:
# Expectancy
#
# 0
# IDENTICAL
# original_text =   Kvetching
# predicted text = Kvetching
#
# WORD:
# Kvetching
#
# 0
# IDENTICAL
# original_text =   SNOOTILY
# predicted text = SNOOTILY
#
# WORD:
# SNOOTILY
#
# 0
# IDENTICAL
# original_text =   THYMUSES
# predicted text = THYMUSES
#
# WORD:
# THYMUSES
#
# 0
# IDENTICAL
# original_text =   COHERED
# predicted text = EOBERED
#
# WORD:
# EOBERED
#
# 2
# NOT IDENTICAL
# original_text =   cumbersomeness
# predicted text = cumbersomeness
#
# WORD:
# cumbersomeness
#
# 0
# IDENTICAL
# original_text =   KRISTIE
# predicted text = KRISTE
#
# WORD:
# KRISTE
#
# 1
# NOT IDENTICAL
# original_text =   Graham
# predicted text = Craham
#
# WORD:
# Craham
#
# 1
# NOT IDENTICAL
# original_text =   Forrest
# predicted text = Forrest
#
# WORD:
# Forrest
#
# 0
# IDENTICAL
# original_text =   DOMESDAY
# predicted text = DOMESDAY
#
# WORD:
# DOMESDAY
#
# 0
# IDENTICAL
# original_text =   MATH
# predicted text = MATH
#
# WORD:
# MATH
#
# 0
# IDENTICAL
# original_text =   Unattached
# predicted text = Iestoas
#
# WORD:
# Iestoas
#
# 8
# NOT IDENTICAL
# original_text =   Lakota
# predicted text = lakots
#
# WORD:
# lakots
#
# 2
# NOT IDENTICAL
# original_text =   PLATFORMED
# predicted text = PLATFORMEd
#
# WORD:
# PLATFORMEd
#
# 1
# NOT IDENTICAL
# original_text =   Orthographies
# predicted text = Orthographies
#
# WORD:
# Orthographies
#
# 0
# IDENTICAL
# original_text =   Chantey
# predicted text = Chantey
#
# WORD:
# Chantey
#
# 0
# IDENTICAL
# original_text =   Gamete
# predicted text = Camala
#
# WORD:
# Camala
#
# 4
# NOT IDENTICAL
# original_text =   RACKED
# predicted text = RACKED
#
# WORD:
# RACKED
#
# 0
# IDENTICAL
# original_text =   COMMUNICATIVE
# predicted text = COMMUNICATIVE
#
# WORD:
# COMMUNICATIVE
#
# 0
# IDENTICAL
# original_text =   PANIER
# predicted text = PANIER
#
# WORD:
# PANIER
#
# 0
# IDENTICAL
# original_text =   covetously
# predicted text = covetously
#
# WORD:
# covetously
#
# 0
# IDENTICAL
# original_text =   conclusion
# predicted text = conclusion
#
# WORD:
# conclusion
#
# 0
# IDENTICAL
# original_text =   instructive
# predicted text = instructive
#
# WORD:
# instructive
#
# 0
# IDENTICAL
# original_text =   Toff
# predicted text = Toff
#
# WORD:
# Toff
#
# 0
# IDENTICAL
# original_text =   KNUTHS
# predicted text = KNUTHS
#
# WORD:
# KNUTHS
#
# 0
# IDENTICAL
# original_text =   lob
# predicted text = lob
#
# WORD:
# lob
#
# 0
# IDENTICAL
# original_text =   TVA
# predicted text = TVA
#
# WORD:
# TVA
#
# 0
# IDENTICAL
# original_text =   CENSORIOUSNESS
# predicted text = AASORFCUSNESS
#
# WORD:
# AASORFCUSNESS
#
# 5
# NOT IDENTICAL
# original_text =   autocrats
# predicted text = autocrats
#
# WORD:
# autocrats
#
# 0
# IDENTICAL
# original_text =   blamelessly
# predicted text = blamelessly
#
# WORD:
# blamelessly
#
# 0
# IDENTICAL
# original_text =   reproaches
# predicted text = reproaches
#
# WORD:
# reproaches
#
# 0
# IDENTICAL
# original_text =   STORY
# predicted text = STORY
#
# WORD:
# STORY
#
# 0
# IDENTICAL
# original_text =   amnesties
# predicted text = amnesties
#
# WORD:
# amnesties
#
# 0
# IDENTICAL
# original_text =   bulganin
# predicted text = bulganin
#
# WORD:
# bulganin
#
# 0
# IDENTICAL
# original_text =   Hideaway
# predicted text = Hideaway
#
# WORD:
# Hideaway
#
# 0
# IDENTICAL
# original_text =   Inference
# predicted text = Inference
#
# WORD:
# Inference
#
# 0
# IDENTICAL
# original_text =   geophysicist
# predicted text = geoplysiciod
#
# WORD:
# geoplysiciod
#
# 3
# NOT IDENTICAL
# original_text =   chapels
# predicted text = chapels
#
# WORD:
# chapels
#
# 0
# IDENTICAL
# original_text =   UNSADDLED
# predicted text = UNSADdLEr
#
# WORD:
# UNSADdLEr
#
# 2
# NOT IDENTICAL
# original_text =   Leos
# predicted text = Leos
#
# WORD:
# Leos
#
# 0
# IDENTICAL
# original_text =   CONTEMPLATES
# predicted text = CONTEMPLATES
#
# WORD:
# CONTEMPLATES
#
# 0
# IDENTICAL
# original_text =   shoddy
# predicted text = shoddy
#
# WORD:
# shoddy
#
# 0
# IDENTICAL
# original_text =   UNDERPRODUCTION
# predicted text = UNDERPROOUCTION
#
# WORD:
# UNDERPROOUCTION
#
# 1
# NOT IDENTICAL
# original_text =   metricates
# predicted text = metricates
#
# WORD:
# metricates
#
# 0
# IDENTICAL
# original_text =   Discounter
# predicted text = Discounter
#
# WORD:
# Discounter
#
# 0
# IDENTICAL
# original_text =   POSTBAGS
# predicted text = POSTEAYS
#
# WORD:
# POSTEAYS
#
# 2
# NOT IDENTICAL
# original_text =   bubbled
# predicted text = bubbled
#
# WORD:
# bubbled
#
# 0
# IDENTICAL
# original_text =   TRIALED
# predicted text = IRIALED
#
# WORD:
# IRIALED
#
# 1
# NOT IDENTICAL
# original_text =   COMPARTMENTALIZING
# predicted text = COMPARITVENTALIZING
#
# WORD:
# COMPARITVENTALIZING
#
# 2
# NOT IDENTICAL
# original_text =   Nazi
# predicted text = Nazi
#
# WORD:
# Nazi
#
# 0
# IDENTICAL
# original_text =   Portiere
# predicted text = Purticre
#
# WORD:
# Purticre
#
# 2
# NOT IDENTICAL
# original_text =   TWIGGING
# predicted text = TWIGGING
#
# WORD:
# TWIGGING
#
# 0
# IDENTICAL
# original_text =   LAUNDRESS
# predicted text = LAUNDRESS
#
# WORD:
# LAUNDRESS
#
# 0
# IDENTICAL
# original_text =   grotesque
# predicted text = grcresque
#
# WORD:
# grcresque
#
# 2
# NOT IDENTICAL
# original_text =   Peregrinate
# predicted text = PeRAHtNN
#
# WORD:
# PeRAHtNN
#
# 9
# NOT IDENTICAL
# original_text =   LETTERHEADS
# predicted text = LETTERHEADS
#
# WORD:
# LETTERHEADS
#
# 0
# IDENTICAL
# original_text =   Griming
# predicted text = GRIMING
#
# WORD:
# GRIMING
#
# 6
# NOT IDENTICAL
# original_text =   Pontifically
# predicted text = Pontifically
#
# WORD:
# Pontifically
#
# 0
# IDENTICAL
# original_text =   cardiology
# predicted text = candiology
#
# WORD:
# candiology
#
# 1
# NOT IDENTICAL
# original_text =   Jilted
# predicted text = lited
#
# WORD:
# lited
#
# 2
# NOT IDENTICAL
# original_text =   Slumped
# predicted text = Slumpei
#
# WORD:
# Slumpei
#
# 1
# NOT IDENTICAL
# original_text =   disembodiment
# predicted text = disemeodiment
#
# WORD:
# disemeodiment
#
# 1
# NOT IDENTICAL
# original_text =   Instituter
# predicted text = Instituter
#
# WORD:
# Instituter
#
# 0
# IDENTICAL
# original_text =   Actaeon
# predicted text = Actaeon
#
# WORD:
# Actaeon
#
# 0
# IDENTICAL
# original_text =   clefts
# predicted text = cleits
#
# WORD:
# cleits
#
# 1
# NOT IDENTICAL
# original_text =   apexes
# predicted text = apexes
#
# WORD:
# apexes
#
# 0
# IDENTICAL
# original_text =   Orbiter
# predicted text = Orbiter
#
# WORD:
# Orbiter
#
# 0
# IDENTICAL
# original_text =   STRICT
# predicted text = STRICT
#
# WORD:
# STRICT
#
# 0
# IDENTICAL
# original_text =   Fingerprinted
# predicted text = Fingesprinted
#
# WORD:
# Fingesprinted
#
# 1
# NOT IDENTICAL
# original_text =   Aerobically
# predicted text = Asobitally
#
# WORD:
# Asobitally
#
# 3
# NOT IDENTICAL
# original_text =   insertions
# predicted text = insertions
#
# WORD:
# insertions
#
# 0
# IDENTICAL
# original_text =   coronado
# predicted text = caranado
#
# WORD:
# caranado
#
# 2
# NOT IDENTICAL
# original_text =   rejigs
# predicted text = refigs
#
# WORD:
# refigs
#
# 1
# NOT IDENTICAL
# original_text =   Pankhurst
# predicted text = Pankhurst
#
# WORD:
# Pankhurst
#
# 0
# IDENTICAL
# original_text =   lucked
# predicted text = lrcked
#
# WORD:
# lrcked
#
# 1
# NOT IDENTICAL
# original_text =   Standoff
# predicted text = Standoff
#
# WORD:
# Standoff
#
# 0
# IDENTICAL
# original_text =   STIMULATE
# predicted text = STIMULATE
#
# WORD:
# STIMULATE
#
# 0
# IDENTICAL
# original_text =   desiring
# predicted text = desiring
#
# WORD:
# desiring
#
# 0
# IDENTICAL
# original_text =   received
# predicted text = received
#
# WORD:
# received
#
# 0
# IDENTICAL
# original_text =   Distribution
# predicted text = Distribution
#
# WORD:
# Distribution
#
# 0
# IDENTICAL
# original_text =   breathalyzes
# predicted text = breathalyzes
#
# WORD:
# breathalyzes
#
# 0
# IDENTICAL
# original_text =   Untrustworthy
# predicted text = Untrushworting
#
# WORD:
# Untrushworting
#
# 4
# NOT IDENTICAL
# original_text =   derv
# predicted text = derv
#
# WORD:
# derv
#
# 0
# IDENTICAL
# original_text =   BAYES
# predicted text = BAYES
#
# WORD:
# BAYES
#
# 0
# IDENTICAL
# original_text =   Penning
# predicted text = Penning
#
# WORD:
# Penning
#
# 0
# IDENTICAL
# original_text =   passels
# predicted text = passels
#
# WORD:
# passels
#
# 0
# IDENTICAL
# original_text =   social
# predicted text = social
#
# WORD:
# social
#
# 0
# IDENTICAL
# original_text =   dvorak
# predicted text = dvorak
#
# WORD:
# dvorak
#
# 0
# IDENTICAL
# original_text =   magnets
# predicted text = magnets
#
# WORD:
# magnets
#
# 0
# IDENTICAL
# original_text =   DILBERTS
# predicted text = DILBERTS
#
# WORD:
# DILBERTS
#
# 0
# IDENTICAL
# original_text =   Impingement
# predicted text = Impingement
#
# WORD:
# Impingement
#
# 0
# IDENTICAL
# original_text =   Timur
# predicted text = Timul
#
# WORD:
# Timul
#
# 1
# NOT IDENTICAL
# original_text =   manitoulin
# predicted text = manitoulin
#
# WORD:
# manitoulin
#
# 0
# IDENTICAL
# original_text =   SODDED
# predicted text = SODDED
#
# WORD:
# SODDED
#
# 0
# IDENTICAL
# original_text =   BACKWASH
# predicted text = BACKWASH
#
# WORD:
# BACKWASH
#
# 0
# IDENTICAL
# original_text =   SPINALS
# predicted text = IPINALI
#
# WORD:
# IPINALI
#
# 2
# NOT IDENTICAL
# original_text =   hydrofoils
# predicted text = hydrofoils
#
# WORD:
# hydrofoils
#
# 0
# IDENTICAL
# original_text =   euthanasia
# predicted text = euthanasia
#
# WORD:
# euthanasia
#
# 0
# IDENTICAL
# original_text =   HARDBALL
# predicted text = HARDBALL
#
# WORD:
# HARDBALL
#
# 0
# IDENTICAL
# original_text =   LEFTMOST
# predicted text = LEFTMOST
#
# WORD:
# LEFTMOST
#
# 0
# IDENTICAL
# original_text =   PHOTOSYNTHESIZED
# predicted text = PHOTOSINTHESIZED
#
# WORD:
# PHOTOSINTHESIZED
#
# 1
# NOT IDENTICAL
# original_text =   inconsistently
# predicted text = inconsistently
#
# WORD:
# inconsistently
#
# 0
# IDENTICAL
# original_text =   sounder
# predicted text = sounder
#
# WORD:
# sounder
#
# 0
# IDENTICAL
# original_text =   Ghosted
# predicted text = Ghosted
#
# WORD:
# Ghosted
#
# 0
# IDENTICAL
# original_text =   JERKS
# predicted text = JERS
#
# WORD:
# JERS
#
# 1
# NOT IDENTICAL
# original_text =   scarceness
# predicted text = scarceness
#
# WORD:
# scarceness
#
# 0
# IDENTICAL
# original_text =   UTTERMOST
# predicted text = UTTERMOST
#
# WORD:
# UTTERMOST
#
# 0
# IDENTICAL
# original_text =   Hogged
# predicted text = Hogged
#
# WORD:
# Hogged
#
# 0
# IDENTICAL
# original_text =   unhelpful
# predicted text = unhelpful
#
# WORD:
# unhelpful
#
# 0
# IDENTICAL
# original_text =   hosting
# predicted text = hosting
#
# WORD:
# hosting
#
# 0
# IDENTICAL
# original_text =   aloft
# predicted text = aloft
#
# WORD:
# aloft
#
# 0
# IDENTICAL
# original_text =   disabling
# predicted text = disabling
#
# WORD:
# disabling
#
# 0
# IDENTICAL
# original_text =   DESERVEDLY
# predicted text = DESERVEDLY
#
# WORD:
# DESERVEDLY
#
# 0
# IDENTICAL
# original_text =   REVELRIES
# predicted text = REVELRIES
#
# WORD:
# REVELRIES
#
# 0
# IDENTICAL
# original_text =   INFIRM
# predicted text = INFIRM
#
# WORD:
# INFIRM
#
# 0
# IDENTICAL
# original_text =   odious
# predicted text = odious
#
# WORD:
# odious
#
# 0
# IDENTICAL
# original_text =   INDISPENSABLY
# predicted text = INDISPENSABLY
#
# WORD:
# INDISPENSABLY
#
# 0
# IDENTICAL
# original_text =   geiger
# predicted text = geiger
#
# WORD:
# geiger
#
# 0
# IDENTICAL
# original_text =   lamaisms
# predicted text = lamaisms
#
# WORD:
# lamaisms
#
# 0
# IDENTICAL
# original_text =   Rickrack
# predicted text = Riekrock
#
# WORD:
# Riekrock
#
# 2
# NOT IDENTICAL
# original_text =   JOSEPHA
# predicted text = JOSEPHA
#
# WORD:
# JOSEPHA
#
# 0
# IDENTICAL
# original_text =   MELD
# predicted text = PD
#
# WORD:
# PD
#
# 3
# NOT IDENTICAL
# original_text =   farads
# predicted text = farads
#
# WORD:
# farads
#
# 0
# IDENTICAL
# original_text =   BUSHEL
# predicted text = BUSHEL
#
# WORD:
# BUSHEL
#
# 0
# IDENTICAL
# original_text =   Revert
# predicted text = Revert
#
# WORD:
# Revert
#
# 0
# IDENTICAL
# original_text =   DENOTE
# predicted text = DENOTE
#
# WORD:
# DENOTE
#
# 0
# IDENTICAL
# original_text =   MOSTLY
# predicted text = MOSTLY
#
# WORD:
# MOSTLY
#
# 0
# IDENTICAL
# original_text =   plumber
# predicted text = plumber
#
# WORD:
# plumber
#
# 0
# IDENTICAL
# original_text =   WUSSIER
# predicted text = WUSSIER
#
# WORD:
# WUSSIER
#
# 0
# IDENTICAL
# original_text =   Absorbs
# predicted text = Absorbs
#
# WORD:
# Absorbs
#
# 0
# IDENTICAL
# original_text =   Moraine
# predicted text = Nasming
#
# WORD:
# Nasming
#
# 5
# NOT IDENTICAL
# original_text =   Grandiose
# predicted text = Grandiose
#
# WORD:
# Grandiose
#
# 0
# IDENTICAL
# original_text =   Solidity
# predicted text = Salsies
#
# WORD:
# Salsies
#
# 5
# NOT IDENTICAL
# original_text =   knowingly
# predicted text = knowingly
#
# WORD:
# knowingly
#
# 0
# IDENTICAL
# original_text =   BASTE
# predicted text = BASTE
#
# WORD:
# BASTE
#
# 0
# IDENTICAL
# original_text =   Ordered
# predicted text = Ordered
#
# WORD:
# Ordered
#
# 0
# IDENTICAL
# original_text =   Hermetically
# predicted text = Hermetically
#
# WORD:
# Hermetically
#
# 0
# IDENTICAL
# original_text =   trobriand
# predicted text = trobriand
#
# WORD:
# trobriand
#
# 0
# IDENTICAL
# original_text =   Flywheel
# predicted text = Flywheel
#
# WORD:
# Flywheel
#
# 0
# IDENTICAL
# original_text =   Steepening
# predicted text = Sleepening
#
# WORD:
# Sleepening
#
# 1
# NOT IDENTICAL
# original_text =   nighthawks
# predicted text = rs
#
# WORD:
# rs
#
# 9
# NOT IDENTICAL
# original_text =   Advantaging
# predicted text = Advantaging
#
# WORD:
# Advantaging
#
# 0
# IDENTICAL
# original_text =   Quark
# predicted text = Quark
#
# WORD:
# Quark
#
# 0
# IDENTICAL
# original_text =   GRATIFYING
# predicted text = GRATIEYING
#
# WORD:
# GRATIEYING
#
# 1
# NOT IDENTICAL
# original_text =   Catheterize
# predicted text = Catheterize
#
# WORD:
# Catheterize
#
# 0
# IDENTICAL
# original_text =   WASTREL
# predicted text = WASTREL
#
# WORD:
# WASTREL
#
# 0
# IDENTICAL
# original_text =   infarcts
# predicted text = infarcts
#
# WORD:
# infarcts
#
# 0
# IDENTICAL
# original_text =   Puffers
# predicted text = PUFFERS
#
# WORD:
# PUFFERS
#
# 6
# NOT IDENTICAL
# original_text =   DROVE
# predicted text = DROVE
#
# WORD:
# DROVE
#
# 0
# IDENTICAL
# original_text =   zoll
# predicted text = zol
#
# WORD:
# zol
#
# 1
# NOT IDENTICAL
# original_text =   Karla
# predicted text = Kaurh
#
# WORD:
# Kaurh
#
# 3
# NOT IDENTICAL
# original_text =   OLDER
# predicted text = OLDER
#
# WORD:
# OLDER
#
# 0
# IDENTICAL
# original_text =   Clogs
# predicted text = Clogs
#
# WORD:
# Clogs
#
# 0
# IDENTICAL
# original_text =   Miscalculate
# predicted text = Miscaiculate
#
# WORD:
# Miscaiculate
#
# 1
# NOT IDENTICAL
# original_text =   alexanders
# predicted text = alezanders
#
# WORD:
# alezanders
#
# 1
# NOT IDENTICAL
# original_text =   Tamperers
# predicted text = Tamperers
#
# WORD:
# Tamperers
#
# 0
# IDENTICAL
# original_text =   Rebelling
# predicted text = Rebelling
#
# WORD:
# Rebelling
#
# 0
# IDENTICAL
# original_text =   STAKE
# predicted text = STAKE
#
# WORD:
# STAKE
#
# 0
# IDENTICAL
# original_text =   Overbid
# predicted text = OVERBID
#
# WORD:
# OVERBID
#
# 6
# NOT IDENTICAL
# original_text =   Elevenths
# predicted text = Elevenths
#
# WORD:
# Elevenths
#
# 0
# IDENTICAL
# original_text =   chadwick
# predicted text = chadwick
#
# WORD:
# chadwick
#
# 0
# IDENTICAL
# original_text =   Maya
# predicted text = Maya
#
# WORD:
# Maya
#
# 0
# IDENTICAL
# original_text =   fatwas
# predicted text = fatwas
#
# WORD:
# fatwas
#
# 0
# IDENTICAL
# original_text =   honorers
# predicted text = honorers
#
# WORD:
# honorers
#
# 0
# IDENTICAL
# original_text =   sandlot
# predicted text = sandlot
#
# WORD:
# sandlot
#
# 0
# IDENTICAL
# original_text =   Doctored
# predicted text = Doctored
#
# WORD:
# Doctored
#
# 0
# IDENTICAL
# original_text =   Glendale
# predicted text = Yendale
#
# WORD:
# Yendale
#
# 2
# NOT IDENTICAL
# original_text =   PILOTHOUSE
# predicted text = PILOTHOUSE
#
# WORD:
# PILOTHOUSE
#
# 0
# IDENTICAL
# original_text =   Misdeed
# predicted text = Misdeed
#
# WORD:
# Misdeed
#
# 0
# IDENTICAL
# original_text =   Berating
# predicted text = Berating
#
# WORD:
# Berating
#
# 0
# IDENTICAL
# original_text =   Poltroon
# predicted text = Poltroon
#
# WORD:
# Poltroon
#
# 0
# IDENTICAL
# original_text =   farmhands
# predicted text = farmhands
#
# WORD:
# farmhands
#
# 0
# IDENTICAL
# original_text =   NONMETALLIC
# predicted text = NONMETALLIC
#
# WORD:
# NONMETALLIC
#
# 0
# IDENTICAL
# original_text =   COLORFUL
# predicted text = COLORFIUL
#
# WORD:
# COLORFIUL
#
# 1
# NOT IDENTICAL
# original_text =   Renovator
# predicted text = Removator
#
# WORD:
# Removator
#
# 1
# NOT IDENTICAL
# original_text =   GAMUT
# predicted text = GAMUT
#
# WORD:
# GAMUT
#
# 0
# IDENTICAL
# original_text =   pavings
# predicted text = pavings
#
# WORD:
# pavings
#
# 0
# IDENTICAL
# original_text =   Importer
# predicted text = Importer
#
# WORD:
# Importer
#
# 0
# IDENTICAL
# original_text =   Smitten
# predicted text = Smitton
#
# WORD:
# Smitton
#
# 1
# NOT IDENTICAL
# original_text =   release
# predicted text = release
#
# WORD:
# release
#
# 0
# IDENTICAL
# original_text =   Haughtier
# predicted text = Haughtier
#
# WORD:
# Haughtier
#
# 0
# IDENTICAL
# original_text =   Stance
# predicted text = Stance
#
# WORD:
# Stance
#
# 0
# IDENTICAL
# original_text =   absolutes
# predicted text = absolutes
#
# WORD:
# absolutes
#
# 0
# IDENTICAL
# original_text =   Dyes
# predicted text = Dyes
#
# WORD:
# Dyes
#
# 0
# IDENTICAL
# original_text =   Consisting
# predicted text = Consisting
#
# WORD:
# Consisting
#
# 0
# IDENTICAL
# original_text =   Humbleness
# predicted text = Humbleness
#
# WORD:
# Humbleness
#
# 0
# IDENTICAL
# original_text =   declining
# predicted text = teclininrs
#
# WORD:
# teclininrs
#
# 3
# NOT IDENTICAL
# original_text =   untarnished
# predicted text = untarnished
#
# WORD:
# untarnished
#
# 0
# IDENTICAL
# original_text =   Downgrade
# predicted text = Downgrade
#
# WORD:
# Downgrade
#
# 0
# IDENTICAL
# original_text =   Eponymous
# predicted text = Eponymos
#
# WORD:
# Eponymos
#
# 1
# NOT IDENTICAL
# original_text =   Feller
# predicted text = Feller
#
# WORD:
# Feller
#
# 0
# IDENTICAL
# original_text =   Unvarying
# predicted text = Unvarying
#
# WORD:
# Unvarying
#
# 0
# IDENTICAL
# original_text =   krasnoyarsk
# predicted text = trasmogoesh
#
# WORD:
# trasmogoesh
#
# 6
# NOT IDENTICAL
# original_text =   Aorta
# predicted text = Aorta
#
# WORD:
# Aorta
#
# 0
# IDENTICAL
# original_text =   Twirls
# predicted text = Twirls
#
# WORD:
# Twirls
#
# 0
# IDENTICAL
# original_text =   Dissipate
# predicted text = Dissipate
#
# WORD:
# Dissipate
#
# 0
# IDENTICAL
# original_text =   stinkier
# predicted text = sintier
#
# WORD:
# sintier
#
# 2
# NOT IDENTICAL
# original_text =   cliquiest
# predicted text = cliquiest
#
# WORD:
# cliquiest
#
# 0
# IDENTICAL
# original_text =   SUBWAY
# predicted text = SUBWAY
#
# WORD:
# SUBWAY
#
# 0
# IDENTICAL
# original_text =   Executioner
# predicted text = Executioner
#
# WORD:
# Executioner
#
# 0
# IDENTICAL
# original_text =   UNDEREXPOSING
# predicted text = UNDEREXPOSING
#
# WORD:
# UNDEREXPOSING
#
# 0
# IDENTICAL
# original_text =   Argot
# predicted text = Argot
#
# WORD:
# Argot
#
# 0
# IDENTICAL
# original_text =   STIRRINGS
# predicted text = STIRRINGS
#
# WORD:
# STIRRINGS
#
# 0
# IDENTICAL
# original_text =   Shabbiest
# predicted text = Shabbiest
#
# WORD:
# Shabbiest
#
# 0
# IDENTICAL
# original_text =   Straighten
# predicted text = Straighten
#
# WORD:
# Straighten
#
# 0
# IDENTICAL
# original_text =   Palisades
# predicted text = Polsodes
#
# WORD:
# Polsodes
#
# 3
# NOT IDENTICAL
# original_text =   FUZZ
# predicted text = FUZZ
#
# WORD:
# FUZZ
#
# 0
# IDENTICAL
# original_text =   DEFEND
# predicted text = DEFEND
#
# WORD:
# DEFEND
#
# 0
# IDENTICAL
# original_text =   SHADOWBOXED
# predicted text = Saforsones
#
# WORD:
# Saforsones
#
# 10
# NOT IDENTICAL
# original_text =   grouched
# predicted text = grouched
#
# WORD:
# grouched
#
# 0
# IDENTICAL
# original_text =   Imperfect
# predicted text = imperfect
#
# WORD:
# imperfect
#
# 1
# NOT IDENTICAL
# original_text =   COLDEST
# predicted text = COLAEST
#
# WORD:
# COLAEST
#
# 1
# NOT IDENTICAL
# original_text =   actuation
# predicted text = actuation
#
# WORD:
# actuation
#
# 0
# IDENTICAL
# original_text =   Inlet
# predicted text = Inlet
#
# WORD:
# Inlet
#
# 0
# IDENTICAL
# original_text =   OUTBUILDING
# predicted text = OUTBUILDING
#
# WORD:
# OUTBUILDING
#
# 0
# IDENTICAL
# original_text =   Kenmore
# predicted text = Kenmore
#
# WORD:
# Kenmore
#
# 0
# IDENTICAL
# original_text =   rotary
# predicted text = rotars
#
# WORD:
# rotars
#
# 1
# NOT IDENTICAL
# original_text =   Combining
# predicted text = Combining
#
# WORD:
# Combining
#
# 0
# IDENTICAL
# original_text =   Millionths
# predicted text = Millionths
#
# WORD:
# Millionths
#
# 0
# IDENTICAL
# original_text =   vacationer
# predicted text = vacationer
#
# WORD:
# vacationer
#
# 0
# IDENTICAL
# original_text =   Bia
# predicted text = Bia
#
# WORD:
# Bia
#
# 0
# IDENTICAL
# original_text =   Ritzy
# predicted text = Rizy
#
# WORD:
# Rizy
#
# 1
# NOT IDENTICAL
# original_text =   hairpins
# predicted text = hairpins
#
# WORD:
# hairpins
#
# 0
# IDENTICAL
# original_text =   Nightsticks
# predicted text = Nghtstioks
#
# WORD:
# Nghtstioks
#
# 2
# NOT IDENTICAL
# original_text =   claptrap
# predicted text = claptrap
#
# WORD:
# claptrap
#
# 0
# IDENTICAL
# original_text =   Deducted
# predicted text = Deducted
#
# WORD:
# Deducted
#
# 0
# IDENTICAL
# original_text =   rocket
# predicted text = recked
#
# WORD:
# recked
#
# 2
# NOT IDENTICAL
# original_text =   fuzzy
# predicted text = fuesy
#
# WORD:
# fuesy
#
# 2
# NOT IDENTICAL
# original_text =   EFFENDI
# predicted text = EFFENDI
#
# WORD:
# EFFENDI
#
# 0
# IDENTICAL
# original_text =   featherbedding
# predicted text = FEITHERDESNING
#
# WORD:
# FEITHERDESNING
#
# 14
# NOT IDENTICAL
# original_text =   shiner
# predicted text = sriner
#
# WORD:
# sriner
#
# 1
# NOT IDENTICAL
# original_text =   jug
# predicted text = jug
#
# WORD:
# jug
#
# 0
# IDENTICAL
# original_text =   CONSEQUENTIALLY
# predicted text = CONSEQUENTIALY
#
# WORD:
# CONSEQUENTIALY
#
# 1
# NOT IDENTICAL
# original_text =   extortionists
# predicted text = extortionists
#
# WORD:
# extortionists
#
# 0
# IDENTICAL
# original_text =   dimity
# predicted text = dimity
#
# WORD:
# dimity
#
# 0
# IDENTICAL
# original_text =   CLIFFORD
# predicted text = CLIFFORD
#
# WORD:
# CLIFFORD
#
# 0
# IDENTICAL
# original_text =   Wickets
# predicted text = Wickets
#
# WORD:
# Wickets
#
# 0
# IDENTICAL
# original_text =   DUMPS
# predicted text = DUMPS
#
# WORD:
# DUMPS
#
# 0
# IDENTICAL
# original_text =   BACKBREAKING
# predicted text = BACKBREAKING
#
# WORD:
# BACKBREAKING
#
# 0
# IDENTICAL
# original_text =   Lampshade
# predicted text = tampshade
#
# WORD:
# tampshade
#
# 1
# NOT IDENTICAL
# original_text =   Gd
# predicted text = Gd
#
# WORD:
# Gd
#
# 0
# IDENTICAL
# original_text =   Voraciously
# predicted text = Voraciously
#
# WORD:
# Voraciously
#
# 0
# IDENTICAL
# original_text =   TUCKER
# predicted text = TUCKER
#
# WORD:
# TUCKER
#
# 0
# IDENTICAL
# original_text =   pestles
# predicted text = pestiles
#
# WORD:
# pestiles
#
# 1
# NOT IDENTICAL
# original_text =   DEM
# predicted text = DEN
#
# WORD:
# DEN
#
# 1
# NOT IDENTICAL
# original_text =   CHAFED
# predicted text = CHAFED
#
# WORD:
# CHAFED
#
# 0
# IDENTICAL
# original_text =   LILLY
# predicted text = LILLY
#
# WORD:
# LILLY
#
# 0
# IDENTICAL
# original_text =   attaches
# predicted text = attaches
#
# WORD:
# attaches
#
# 0
# IDENTICAL
# original_text =   EXPRESSIVENESS
# predicted text = BAPRESSIVENESS
#
# WORD:
# BAPRESSIVENESS
#
# 2
# NOT IDENTICAL
# original_text =   JERKIEST
# predicted text = JERKIEST
#
# WORD:
# JERKIEST
#
# 0
# IDENTICAL
# original_text =   unabridged
# predicted text = unabridged
#
# WORD:
# unabridged
#
# 0
# IDENTICAL
# original_text =   Lithographed
# predicted text = Lithographed
#
# WORD:
# Lithographed
#
# 0
# IDENTICAL
# original_text =   LAKES
# predicted text = LAKES
#
# WORD:
# LAKES
#
# 0
# IDENTICAL
# original_text =   MIXX
# predicted text = NIXX
#
# WORD:
# NIXX
#
# 1
# NOT IDENTICAL
# original_text =   intuited
# predicted text = intuited
#
# WORD:
# intuited
#
# 0
# IDENTICAL
# original_text =   BLOTTERS
# predicted text = BLOTTERS
#
# WORD:
# BLOTTERS
#
# 0
# IDENTICAL
# original_text =   EXTRAS
# predicted text = EXTRAS
#
# WORD:
# EXTRAS
#
# 0
# IDENTICAL
# original_text =   Underlain
# predicted text = Underkain
#
# WORD:
# Underkain
#
# 1
# NOT IDENTICAL
# original_text =   BREWERS
# predicted text = BREWERS
#
# WORD:
# BREWERS
#
# 0
# IDENTICAL
# original_text =   Unapproved
# predicted text = Unopproved
#
# WORD:
# Unopproved
#
# 1
# NOT IDENTICAL
# original_text =   Estimated
# predicted text = Estimated
#
# WORD:
# Estimated
#
# 0
# IDENTICAL
# original_text =   Scrubbier
# predicted text = Scrubbier
#
# WORD:
# Scrubbier
#
# 0
# IDENTICAL
# original_text =   wired
# predicted text = wired
#
# WORD:
# wired
#
# 0
# IDENTICAL
# original_text =   whites
# predicted text = whites
#
# WORD:
# whites
#
# 0
# IDENTICAL
# original_text =   Puerile
# predicted text = Puerile
#
# WORD:
# Puerile
#
# 0
# IDENTICAL
# original_text =   Realness
# predicted text = Realness
#
# WORD:
# Realness
#
# 0
# IDENTICAL
# original_text =   diane
# predicted text = diane
#
# WORD:
# diane
#
# 0
# IDENTICAL
# original_text =   serenity
# predicted text = senenity
#
# WORD:
# senenity
#
# 1
# NOT IDENTICAL
# original_text =   personification
# predicted text = personification
#
# WORD:
# personification
#
# 0
# IDENTICAL
# original_text =   Empress
# predicted text = EMpress
#
# WORD:
# EMpress
#
# 1
# NOT IDENTICAL
# original_text =   PLEASURED
# predicted text = PLEASURED
#
# WORD:
# PLEASURED
#
# 0
# IDENTICAL
# original_text =   Corvallis
# predicted text = Corvallis
#
# WORD:
# Corvallis
#
# 0
# IDENTICAL
# original_text =   Jocular
# predicted text = Jocular
#
# WORD:
# Jocular
#
# 0
# IDENTICAL
# original_text =   INCONVENIENTLY
# predicted text = INCONVENENTLY
#
# WORD:
# INCONVENENTLY
#
# 1
# NOT IDENTICAL
# original_text =   Shrillness
# predicted text = SurLrneSs
#
# WORD:
# SurLrneSs
#
# 5
# NOT IDENTICAL
# original_text =   ALLOCATIONS
# predicted text = ALLOCATIONS
#
# WORD:
# ALLOCATIONS
#
# 0
# IDENTICAL
# original_text =   steppe
# predicted text = steppe
#
# WORD:
# steppe
#
# 0
# IDENTICAL
# original_text =   Protest
# predicted text = Protest
#
# WORD:
# Protest
#
# 0
# IDENTICAL
# original_text =   Indulging
# predicted text = Indulgting
#
# WORD:
# Indulgting
#
# 1
# NOT IDENTICAL
# original_text =   sluiced
# predicted text = sluiced
#
# WORD:
# sluiced
#
# 0
# IDENTICAL
# original_text =   Hung
# predicted text = HUNG
#
# WORD:
# HUNG
#
# 3
# NOT IDENTICAL
# original_text =   Citigroup
# predicted text = Cetagooup
#
# WORD:
# Cetagooup
#
# 3
# NOT IDENTICAL
# original_text =   transcendentalism
# predicted text = transcendentalism
#
# WORD:
# transcendentalism
#
# 0
# IDENTICAL
# original_text =   blackleg
# predicted text = blacklet
#
# WORD:
# blacklet
#
# 1
# NOT IDENTICAL
# original_text =   Wanked
# predicted text = Wanked
#
# WORD:
# Wanked
#
# 0
# IDENTICAL
# original_text =   Glossiest
# predicted text = Glossiest
#
# WORD:
# Glossiest
#
# 0
# IDENTICAL
# original_text =   piranhas
# predicted text = piramhas
#
# WORD:
# piramhas
#
# 1
# NOT IDENTICAL
# original_text =   Maulers
# predicted text = Maulers
#
# WORD:
# Maulers
#
# 0
# IDENTICAL
# original_text =   houseboy
# predicted text = houseboy
#
# WORD:
# houseboy
#
# 0
# IDENTICAL
# original_text =   precipitates
# predicted text = precipitates
#
# WORD:
# precipitates
#
# 0
# IDENTICAL
# original_text =   expressing
# predicted text = expressing
#
# WORD:
# expressing
#
# 0
# IDENTICAL
# original_text =   Hamming
# predicted text = Hamming
#
# WORD:
# Hamming
#
# 0
# IDENTICAL
# original_text =   blinker
# predicted text = Minbur
#
# WORD:
# Minbur
#
# 4
# NOT IDENTICAL
# original_text =   Creamer
# predicted text = Creamer
#
# WORD:
# Creamer
#
# 0
# IDENTICAL
# original_text =   reverses
# predicted text = reverses
#
# WORD:
# reverses
#
# 0
# IDENTICAL
# original_text =   Instruments
# predicted text = Instruments
#
# WORD:
# Instruments
#
# 0
# IDENTICAL
# original_text =   ALLOTTING
# predicted text = ALLOTINS
#
# WORD:
# ALLOTINS
#
# 2
# NOT IDENTICAL
# original_text =   ESPOUSES
# predicted text = ESPOUSES
#
# WORD:
# ESPOUSES
#
# 0
# IDENTICAL
# original_text =   Libreville
# predicted text = LBREVILLE
#
# WORD:
# LBREVILLE
#
# 9
# NOT IDENTICAL
# original_text =   Porcelains
# predicted text = Porcelsins
#
# WORD:
# Porcelsins
#
# 1
# NOT IDENTICAL
# original_text =   mesas
# predicted text = MesaS
#
# WORD:
# MesaS
#
# 2
# NOT IDENTICAL
# original_text =   Broker
# predicted text = broker
#
# WORD:
# broker
#
# 1
# NOT IDENTICAL
# original_text =   MOGGY
# predicted text = MOGGY
#
# WORD:
# MOGGY
#
# 0
# IDENTICAL
# original_text =   Mysterious
# predicted text = Mysterious
#
# WORD:
# Mysterious
#
# 0
# IDENTICAL
# original_text =   ANNOUNCES
# predicted text = ANNOUNCES
#
# WORD:
# ANNOUNCES
#
# 0
# IDENTICAL
# original_text =   Nominates
# predicted text = Norminates
#
# WORD:
# Norminates
#
# 1
# NOT IDENTICAL
# original_text =   TRANSACTS
# predicted text = TRANSACTS
#
# WORD:
# TRANSACTS
#
# 0
# IDENTICAL
# original_text =   costing
# predicted text = costing
#
# WORD:
# costing
#
# 0
# IDENTICAL
# original_text =   unexploited
# predicted text = unexolaited
#
# WORD:
# unexolaited
#
# 2
# NOT IDENTICAL
# original_text =   reenlisted
# predicted text = Reenlisted
#
# WORD:
# Reenlisted
#
# 1
# NOT IDENTICAL
# original_text =   DURABLE
# predicted text = DURABLF
#
# WORD:
# DURABLF
#
# 1
# NOT IDENTICAL
# original_text =   REJOICINGS
# predicted text = ReJoiCinGs
#
# WORD:
# ReJoiCinGs
#
# 6
# NOT IDENTICAL
# original_text =   Couturier
# predicted text = Couturier
#
# WORD:
# Couturier
#
# 0
# IDENTICAL
# original_text =   snark
# predicted text = snark
#
# WORD:
# snark
#
# 0
# IDENTICAL
# original_text =   radiologist
# predicted text = rablbloglet
#
# WORD:
# rablbloglet
#
# 5
# NOT IDENTICAL
# DISTANCE:
# (50000,)
# 0.84616
# ACCURACY:
# (50000,)
# 0.72178
# ACCURACY ADJUSTED:
# (50000,)
# 0.8877088865382983
# CORRECT SHAPE:
# (13911,)
# INCORRECT SHAPE:
# (13911,)

# %%
distances_incorrect = []

for i in range(len(correct)):

  print(correct[i].lower())
  print(incorrect[i].lower())
  print()
  distances_incorrect.append(distance(correct[i].lower(), incorrect[i].lower()))

print(np.shape(distances_incorrect))
print(np.mean(distances_incorrect))
# Out:
# Streaming output truncated to the last 5000 lines.
# brainier
# brainer
#
# bill
# cll
#
# mussolini
# mussolin
#
# brag
# brag
#
# falconry
# faleonry
#
# baptiste
# boptisno
#
# electrification
# rectrification
#
# volition
# mniton
#
# doming
# coming
#
# overwhelms
# qverwheims
#
# reinvigorated
# reinvigoroted
#
# daiquiri
# daicur
#
# sweetener
# swebiener
#
# pennyweights
# hinnades
#
# pettifogs
# hetengs
#
# tyrannosaurus
# tyrannosaupus
#
# rubbishing
# rubblshing
#
# recondition
# reconiytion
#
# nannys
# nonnys
#
# mcclain
# meclain
#
# heartless
# hcartless
#
# sacrifice
# sacritice
#
# riderless
# hdiress
#
# franco
# mraed
#
# somali
# bomafi
#
# modicum
# modicun
#
# pantomimed
# rshithihed
#
# quartered
# quattered
#
# earnests
# parnests
#
# ruffly
# nufly
#
# gnocchi
# cs
#
# irretrievable
# trretrivabie
#
# grieg
# griec
#
# tinged
# uinged
#
# signalized
# signalized
#
# bleakly
# bleckly
#
# flawed
# flawep
#
# segregates
# segregates
#
# kline
# kine
#
# charlatanism
# charlatonism
#
# ambassador
# anbassador
#
# languorously
# lancuorously
#
# resewing
# resing
#
# purgers
# nurgers
#
# iotas
# tatoap
#
# labyrinthine
# babvrenpeiee
#
# equivocated
# equiyocated
#
# splat
# aplat
#
# soothingly
# szethingly
#
# brontosaurs
# brontosurs
#
# swordfish
# swordfish
#
# overgrazes
# overbrazes
#
# ritualistically
# nitualistically
#
# extracts
# eixtracts
#
# exacerbating
# macenbrting
#
# roulette
# rovlette
#
# hardcore
# harcone
#
# pennsylvanians
# pennsylvanians
#
# frauen
# eraune
#
# terrorism
# turrorism
#
# bergman
# boryman
#
# validating
# ralprsns
#
# risky
# risicy
#
# negligees
# necligees
#
# concealing
# concenling
#
# weyden
# wpden
#
# pyramids
# byramids
#
# slavic
# slavie
#
# fellowships
# heoeulns
#
# schoolkids
# seheclkids
#
# thirstily
# thrstily
#
# immaturity
# imaturity
#
# seedling
# beebfing
#
# beauregard
# borarigeng
#
# springlike
# springhke
#
# grows
# grauls
#
# conservator
# conservatof
#
# surprising
# stptising
#
# bicyclist
# bicyelist
#
# unsportsmanlike
# uasforisnvanlire
#
# recheck
# reluik
#
# sensitivities
# sennsitivities
#
# oligarchs
# ollgarehs
#
# memento
# memanto
#
# salves
# jaived
#
# worrying
# worfying
#
# stumps
# stumos
#
# liverish
# tvans
#
# dermott
# dermcher
#
# maine
# haine
#
# nacional
# nadlonal
#
# confidential
# ponfidentioll
#
# smote
# smote
#
# resigning
# resgaing
#
# chairmanship
# charmanship
#
# tirades
# tiraves
#
# buckram
# buckrar
#
# gatekeeper
# gatahesper
#
# tito
# turo
#
# gasoline
# basoline
#
# steeples
# steeples
#
# bacteriologists
# bacterlologists
#
# hallelujahs
# halechuiahs
#
# met
# met
#
# labradors
# labradors
#
# midyears
# midvears
#
# agassiz
# ugassts
#
# bears
# pears
#
# disrespectful
# disrespectfur
#
# usurers
# ueurars
#
# solemnities
# solemintes
#
# antisemitic
# antegueve
#
# apologetically
# apologeticaly
#
# leggier
# leccier
#
# inventions
# inventirng
#
# presentation
# presetation
#
# cater
# oater
#
# stan
# start
#
# mussing
# mussing
#
# netherworld
# netherhorld
#
# inadvertent
# inadverteni
#
# coursework
# coursework
#
# dubiously
# dubilously
#
# ascertainment
# aistertaiomeny
#
# lard
# lard
#
# smattering
# smittering
#
# foreshortens
# toreshortens
#
# enervating
# therruling
#
# mudguard
# mudguard
#
# dehydration
# dgerarton
#
# limiting
# linmiting
#
# reciprocated
# resiprecated
#
# turbochargers
# turbocharcers
#
# terminators
# braes
#
# praetors
# srs
#
# pilloried
# pioried
#
# gigs
# cigs
#
# squatted
# squarted
#
# phonying
# phonging
#
# advertises
# advertiscs
#
# irradiate
# szs
#
# matures
# kerbie
#
# retrogressing
# retrogrossing
#
# wafers
# wafers
#
# alcatraz
# alcatzaz
#
# cooing
# cooing
#
# aiken
# auen
#
# splurged
# splurged
#
# 1770
# 11z0
#
# catechizes
# catechizes
#
# maui
# maui
#
# mollusks
# mollusics
#
# vilyui
# vilgal
#
# unitus
# upitus
#
# maltese
# malliess
#
# xerxes
# xetxes
#
# carpetbagger
# carpetboagger
#
# nagasaki
# nagasaki
#
# rydberg
# dydberg
#
# santivanez
# sentuybmet
#
# hippy
# mppy
#
# highhanded
# hichhanded
#
# shillings
# shilings
#
# suppressible
# jupprerrible
#
# facilitation
# fadilation
#
# feedlot
# teedldt
#
# cockroach
# takssdsb
#
# transmits
# trenemits
#
# acceded
# accrded
#
# formulator
# faies
#
# legitimates
# lecitimates
#
# daylight
# daylitte
#
# dispossessing
# diepossessing
#
# negligently
# neguigently
#
# occidentals
# occidentais
#
# assiduousness
# pesiouoteness
#
# yucatan
# jucatan
#
# conspirator
# consprator
#
# speciously
# snecidush
#
# prestige
# prestige
#
# marin
# marin
#
# colosseum
# corlosseln
#
# due
# due
#
# resets
# resets
#
# fornicate
# foaoetee
#
# jellies
# tellies
#
# eminences
# cmcolonn
#
# surgeon
# sugeon
#
# essene
# coneile
#
# lepus
# ropws
#
# noels
# leats
#
# witlessly
# witlaasty
#
# shaft
# shafi
#
# comintern
# comintem
#
# barbie
# beable
#
# scummier
# scummied
#
# freeman
# iduman
#
# commonplace
# commonflns
#
# sneakily
# sneakily
#
# hospitably
# hospirably
#
# vogue
# togue
#
# classification
# classirication
#
# epistles
# episties
#
# dictatorships
# pietatorshlips
#
# estrangement
# estrangement
#
# rightmost
# rightmest
#
# grittier
# griffier
#
# dollies
# dolies
#
# effendis
# effendis
#
# narraganset
# narragansed
#
# antiphonals
# anhphonals
#
# sara
# sard
#
# algorithms
# algntithms
#
# sapping
# sapping
#
# enfranchises
# entranchises
#
# gastropods
# cestropods
#
# ganglion
# gunglion
#
# thornton
# thurntel
#
# falseness
# curtinsts
#
# circumcised
# cellcels
#
# decimeter
# pegimeter
#
# schmoozers
# schinouzers
#
# reflectors
# rilmiciors
#
# haversack
# iasersach
#
# crackpots
# caechms
#
# abashing
# abashing
#
# curtains
# curtains
#
# scarcities
# scarcities
#
# incl
# tay
#
# frederic
# puaderig
#
# muddier
# muddier
#
# subsidiaries
# suesidiarres
#
# wriggly
# wriggily
#
# reproachfully
# reproachfuly
#
# arithmetical
# arihmetical
#
# raft
# rafl
#
# unnamed
# unoumnd
#
# pistols
# potols
#
# malpractice
# malpragtice
#
# grotto
# arotto
#
# overfond
# overiond
#
# botchers
# bothis
#
# schematized
# schematized
#
# excavations
# excayations
#
# glycogen
# clycocen
#
# subsume
# dsss
#
# advises
# advises
#
# mama
# dadua
#
# whitehead
# whitehead
#
# understate
# understate
#
# blur
# blup
#
# coastlines
# coastlines
#
# limpid
# limpio
#
# paige
# paice
#
# springiness
# sdringiness
#
# bulging
# blging
#
# pretty
# pretity
#
# buzz
# dz
#
# mojaves
# mijenss
#
# indefinably
# noefinably
#
# water
# tater
#
# pirouetted
# piroueted
#
# introspective
# itboopigtng
#
# dunks
# duxks
#
# redeployed
# redeprozed
#
# baldness
# baldness
#
# nonindependent
# neinindependent
#
# ginsu
# cinsy
#
# appurtenance
# appurtenaince
#
# privatization
# privatization
#
# demagoguery
# demageqully
#
# middlemen
# vidrendy
#
# caravaggio
# caraongsio
#
# mistresses
# mistnesses
#
# curled
# curded
#
# peashooter
# penshortzs
#
# inaccurate
# naccurate
#
# fivers
# buers
#
# blacklists
# bsudists
#
# troyes
# troves
#
# elizabethan
# elizabethak
#
# nazarene
# nazarene
#
# exclaimed
# excloimed
#
# compressing
# comipressing
#
# backpedaled
# backpoald
#
# genuine
# genvine
#
# deregulating
# beregulating
#
# nonviolently
# nontiotentiy
#
# spiv
# spiy
#
# incarnadining
# pcannanies
#
# overbuying
# overbuving
#
# adjudicated
# lodiated
#
# inveterate
# iveterate
#
# agreeable
# agrecable
#
# motherboard
# hotherboand
#
# entanglements
# entonglements
#
# pouts
# ponts
#
# psychogenic
# sychogent
#
# blastoffs
# bartoffs
#
# kaohsiung
# kaohsiong
#
# mantissas
# mantisses
#
# plonks
# blonks
#
# bowel
# boxiel
#
# spectrometer
# speetroneter
#
# mitts
# miccs
#
# misreported
# fiseeported
#
# bejeweling
# brifhees
#
# rostrum
# restrum
#
# endeavors
# endeavors
#
# analogousness
# enatogousnsss
#
# pugilism
# pugism
#
# regeneration
# reseneration
#
# inadequacies
# midequaces
#
# therapeutic
# dosrepnsis
#
# packinghouses
# pachinghouses
#
# griper
# cniplr
#
# deferral
# deperral
#
# meteorite
# neieaie
#
# refold
# refoid
#
# tactic
# taftkf
#
# proposer
# pronoser
#
# prostate
# prosiate
#
# hillier
# hilier
#
# hyper
# trper
#
# upstaged
# upstaced
#
# slays
# slays
#
# booting
# boating
#
# mealy
# moaly
#
# clangor
# smed
#
# speakerphone
# speamerphons
#
# monkey
# monkelt
#
# victual
# dotuly
#
# benaroya
# benaroya
#
# floodlit
# eloodlit
#
# ravishment
# nutrmens
#
# recession
# recession
#
# carping
# barping
#
# interloping
# intengins
#
# clvii
# clyi
#
# benzine
# bezns
#
# tries
# trier
#
# effused
# ehponed
#
# berths
# berths
#
# impugns
# impuens
#
# frauen
# frauen
#
# lapses
# lapsed
#
# bright
# hught
#
# showgirl
# showgiul
#
# rerouted
# rerus
#
# ordination
# ordination
#
# connecticut
# connecticut
#
# shellacs
# shellacs
#
# intestate
# ligestate
#
# patellae
# raitstlae
#
# plunderer
# pluinderer
#
# ceremonious
# cereronions
#
# colonist
# cntonist
#
# struck
# sobugk
#
# highlighted
# highighted
#
# invariably
# invaricbly
#
# connection
# contucton
#
# wading
# wadlbns
#
# drizzly
# drila
#
# octopuses
# dsteuses
#
# croquet
# croguet
#
# townees
# rowneps
#
# manumission
# manurission
#
# whitenings
# torteet
#
# antsy
# antsy
#
# chihuahuas
# chibunhuns
#
# understandable
# understandbable
#
# que
# gue
#
# owner
# ownet
#
# revelers
# cee
#
# micrometer
# micrometer
#
# facial
# fakial
#
# cuddle
# cubble
#
# counseling
# counseriing
#
# pickaxing
# pickaring
#
# akihito
# akihits
#
# cataclysmal
# cataclismal
#
# vacuoles
# caicuoies
#
# hammock
# hanmocb
#
# decontaminated
# necontaminated
#
# liveried
# liverias
#
# bequests
# hequests
#
# redoubles
# redoubles
#
# emergence
# emergence
#
# machinate
# machinots
#
# immobilizers
# tonobitiers
#
# plights
# pligiits
#
# appoints
# sas
#
# biopics
# biopies
#
# peck
# sas
#
# incursions
# iacursions
#
# soil
# lol
#
# trampling
# trempling
#
# hellion
# hellion
#
# flab
# play
#
# reduplicated
# reduphcazed
#
# unspeakably
# unifeutally
#
# discontented
# dacermonted
#
# hiving
# hiving
#
# pillager
# pileger
#
# monkeyed
# moekeyed
#
# millard
# millard
#
# reside
# pes
#
# farewells
# inrowcils
#
# ingrown
# rngtown
#
# classify
# clasaikly
#
# horniest
# korifest
#
# contrivers
# contrivers
#
# uncoupling
# uncoupling
#
# muzzily
# mnuzsily
#
# uprightly
# uprigihelly
#
# indissoluble
# indissolusle
#
# after
# after
#
# unmemorable
# unnenoraree
#
# unreel
# unreel
#
# antitoxin
# oailing
#
# demonetization
# denonetization
#
# congratulatory
# congrstulatory
#
# audiotapes
# andistnper
#
# depoliticize
# depolaticize
#
# steeliness
# steeliness
#
# bluesy
# bcuesy
#
# schrieffer
# sairieffen
#
# tammany
# lasmss
#
# something
# somathing
#
# glaringly
# olarinoly
#
# instantaneous
# instantanecls
#
# quintupled
# qurintupled
#
# doltishly
# butizhly
#
# bratwursts
# braig
#
# automaker
# antomaker
#
# obsequy
# gtrequy
#
# adjective
# adjiective
#
# unadvertised
# unadvertised
#
# rimbaud
# rimboud
#
# speeches
# speeoues
#
# crasser
# carsy
#
# usually
# usualy
#
# behold
# boip
#
# statehouses
# sratchouses
#
# unconcerned
# unconcermed
#
# discontinuances
# discontinuainces
#
# bowdlerized
# iemellosnizeet
#
# referral
# refermal
#
# toques
# toqued
#
# wheeling
# weeling
#
# objectification
# osjectification
#
# slightest
# symel
#
# peristyle
# peristule
#
# flossing
# dessling
#
# videodisc
# videodisc
#
# dimmest
# dimimest
#
# iterating
# hamibng
#
# enzyme
# enlyme
#
# repulsing
# repnlsing
#
# breathlessness
# dreatrlessness
#
# alderamin
# alderhmin
#
# straights
# straights
#
# testing
# testng
#
# pierced
# pcs
#
# wheedler
# wheedier
#
# rssa
# yssa
#
# polygon
# polyoon
#
# leer
# leck
#
# reanalyzing
# teanalyzing
#
# taro
# tary
#
# burring
# iurring
#
# risked
# rized
#
# existences
# dristeners
#
# carnival
# terniial
#
# temped
# teuped
#
# defoliation
# defruntin
#
# slip
# sup
#
# characterful
# choracterful
#
# frailer
# fratler
#
# illicit
# licit
#
# injurer
# onjarer
#
# anglers
# unylers
#
# spooks
# sposks
#
# 1st
# ist
#
# nw
# maa
#
# esophageal
# esophogel
#
# trivialization
# censnicatios
#
# taejon
# cnes
#
# nonuniform
# nonunform
#
# tyrolean
# tprollean
#
# sicilians
# sicilians
#
# meadowlark
# meadiowlark
#
# armful
# armful
#
# vibrancy
# hre
#
# quicksilver
# ouicksilver
#
# toeing
# toeing
#
# lardy
# lardy
#
# freelanced
# trelanced
#
# snakiest
# sobttesu
#
# stradivari
# stradivart
#
# ballads
# pes
#
# chipmunks
# chipmanks
#
# tables
# talaped
#
# micrometers
# mptarabaired
#
# xians
# lns
#
# antoninus
# antonius
#
# hoodwinks
# iccdwinrs
#
# ibadan
# loadan
#
# cls
# cls
#
# foppish
# foppish
#
# chavez
# tias
#
# contemporaneously
# uintinporaneousls
#
# tattles
# t
#
# belfry
# bolfry
#
# splintery
# sphintery
#
# noisemakers
# noisemabets
#
# psychotropics
# intehotrentes
#
# gesticulation
# cesticulation
#
# kontrol
# korrtrol
#
# lawnmowers
# pwmmowvers
#
# regresses
# reeresses
#
# iowan
# lowan
#
# snagged
# fnayged
#
# fwd
# tad
#
# outsourcing
# outnouncing
#
# blueplate
# blleplate
#
# crystallization
# crystalization
#
# quaintest
# ouaintess
#
# spot
# spot
#
# conceited
# concelited
#
# recollection
# recollection
#
# octavio
# octavio
#
# redetermining
# receterminsng
#
# disarmed
# disarned
#
# assaggio
# aazespr
#
# prigs
# dries
#
# bergerac
# isons
#
# friskier
# friskier
#
# bureaucrat
# wreaucrat
#
# clxii
# clxi
#
# tutelary
# tutslany
#
# freakier
# thechier
#
# langmuir
# landmuir
#
# murat
# aurat
#
# swotted
# snpssted
#
# speaker
# spfaker
#
# fishbowls
# fishbovils
#
# armoring
# armoring
#
# alnilam
# alvilam
#
# coyest
# siget
#
# fluid
# fluid
#
# indignantly
# hndignanty
#
# paralleling
# paraleing
#
# harrisburg
# harribirs
#
# arrests
# arrests
#
# lecherousness
# lecherousmehs
#
# charabancs
# chareincs
#
# 02110
# o2lio
#
# cacophonies
# uephoner
#
# demagoguery
# diehgosury
#
# happenstances
# happenstarcls
#
# nuance
# auance
#
# mathew
# nethes
#
# pharmacies
# fharmacies
#
# thermos
# thermas
#
# spiffing
# spifliny
#
# periwig
# periwia
#
# nonflammable
# ronflennakiy
#
# bauds
# bauds
#
# albuminous
# alpuminous
#
# terahertz
# teraherte
#
# stockbreeder
# stockbreedar
#
# antipathetic
# antipathatic
#
# conferencing
# rvating
#
# crisper
# crispes
#
# underlying
# underlying
#
# italics
# ttalics
#
# impermeability
# ce
#
# saab
# sanb
#
# bounces
# bofes
#
# chiseling
# coseling
#
# contemporaneously
# kmporeleg
#
# houseboys
# fouseboys
#
# waitresses
# waitresyes
#
# aluminum
# alluminum
#
# incarnadine
# incarmadine
#
# reconstructions
# reconstrictions
#
# gilliam
# gillam
#
# biodegrades
# biodecrades
#
# sculpturing
# sculphuring
#
# tooters
# ipodens
#
# quadrangles
# quadranglbs
#
# homeless
# homeless
#
# chirps
# crirps
#
# professed
# prafessed
#
# scarce
# starce
#
# poring
# poring
#
# vicegerents
# utcegerents
#
# followings
# follmings
#
# fistfight
# fisteight
#
# hitchers
# hitkhers
#
# streak
# streab
#
# gofers
# sofers
#
# homonym
# honargrn
#
# quetzalcoatl
# quetzacoati
#
# lankier
# lunkier
#
# soothsayer
# sootheaper
#
# minimization
# mnimization
#
# poorness
# poorness
#
# headlight
# hendlicht
#
# chimborazo
# chimborago
#
# extirpating
# ertirpating
#
# sentimentality
# dentimentality
#
# sawbuck
# jawbuck
#
# adequately
# adequazacy
#
# modern
# modehn
#
# goshawk
# goshank
#
# careen
# corgen
#
# gravedigger
# unoieess
#
# pyrite
# pyrfte
#
# paperless
# puperess
#
# snider
# snidlees
#
# resurgences
# wurgenges
#
# homeowner
# hormeowner
#
# bobolink
# boholink
#
# rambo
# rarribo
#
# goofier
# goufier
#
# 1600
# 18oo
#
# kenley
# kenlev
#
# housebreak
# hesnhans
#
# salve
# salve
#
# predisposing
# precisposing
#
# subtle
# subtlie
#
# synergies
# synercies
#
# fellas
# fellus
#
# overpopulate
# orverpopulzre
#
# degenerated
# dsgemerated
#
# wingtips
# vingtips
#
# scrapping
# scrappamg
#
# guildhalls
# guildballs
#
# kidnap
# kdinap
#
# conciseness
# conciseness
#
# grasses
# bs
#
# rainfalls
# ranfalls
#
# screened
# tened
#
# primal
# prival
#
# androgenic
# androgeric
#
# soil
# sotl
#
# mom
# mioni
#
# contextually
# maty
#
# waggles
# naggles
#
# leitmotivs
# rmgvs
#
# sindhi
# docns
#
# wanderings
# wvendernigs
#
# academia
# tarries
#
# bellini
# bellins
#
# lawmaking
# lawmaling
#
# chancellorsville
# chancellorsvile
#
# generalizations
# behermlratiers
#
# amercements
# amercements
#
# stumblers
# stunmbiers
#
# powwows
# powwows
#
# ghostwriters
# chostwriters
#
# pinpoints
# prponts
#
# impellers
# supellers
#
# recriminating
# recribonating
#
# arsenal
# arsenar
#
# estimated
# sstinatrd
#
# osteoarthritis
# pstcoarthrits
#
# bedeviling
# maeviling
#
# anticipations
# untsreipations
#
# chemurgy
# chamurgs
#
# ales
# alhs
#
# conceptional
# hinmcsepbing
#
# handlery
# handleny
#
# espying
# esryins
#
# corvallis
# corvalls
#
# af
# wf
#
# conjuncture
# coting
#
# impulsiveness
# impullsiveness
#
# sandbags
# sanstogs
#
# recontacts
# recontaots
#
# pointlessly
# pointtessly
#
# swathe
# swatde
#
# poorest
# poozest
#
# senility
# sonalier
#
# compassion
# compassien
#
# barmaids
# reans
#
# satisfaction
# sutisfoction
#
# frolicsome
# frolicsomp
#
# notifications
# sntrnatieos
#
# lemme
# lemme
#
# telltale
# telitale
#
# borough
# aed
#
# occlusion
# acclusion
#
# denominate
# hes
#
# humbug
# hutblg
#
# ecology
# ecology
#
# ruminations
# numinations
#
# placements
# placements
#
# meltdowns
# meitdowns
#
# sealift
# revlift
#
# baronage
# baranage
#
# opiates
# opiazes
#
# plebby
# pems
#
# articulates
# estieulates
#
# tran
# tran
#
# conventions
# cenventiens
#
# fustiness
# fuistiness
#
# reload
# reldad
#
# groveling
# croveling
#
# parochial
# parochia
#
# crosspiece
# ereespieee
#
# leipzig
# leipzis
#
# metamorphic
# mietamorphic
#
# melodies
# nelodies
#
# contrivance
# contrivanee
#
# breakfasted
# breamtasted
#
# sallying
# shllying
#
# ethiopia
# ehiopia
#
# flours
# flourn
#
# unscrupulousness
# unscrupubusness
#
# candlelit
# covdbobit
#
# enunciating
# enunciating
#
# quickly
# quickly
#
# furor
# turer
#
# footpaths
# footpates
#
# cravenly
# crovenly
#
# glad
# glad
#
# obscenest
# obicenest
#
# generalized
# deneralized
#
# frostbit
# frosthit
#
# boomerangs
# bcomerangs
#
# knitter
# knier
#
# latchkeys
# latcekeys
#
# carrycots
# carryoots
#
# docketed
# oocketed
#
# plucked
# pllcked
#
# sorrowfulness
# srroufulness
#
# leapers
# lanpeed
#
# achievement
# acthisvenment
#
# glint
# clint
#
# loudspeakers
# loudspeakers
#
# dali
# dalf
#
# seinfeld
# stavtall
#
# drumstick
# dramstick
#
# ww
# wu
#
# treats
# treats
#
# kinsmen
# kinsimen
#
# ultras
# eltras
#
# handcarts
# handcorts
#
# pagination
# pagination
#
# uselessly
# usclessly
#
# digresses
# dicresses
#
# adjectivally
# aljectivally
#
# bechtel
# beeates
#
# blandish
# sodish
#
# bilingually
# bilingually
#
# repulses
# repylses
#
# significantly
# sionifuantly
#
# nyasa
# nyasa
#
# psychologist
# psychologist
#
# gaff
# gats
#
# enfranchises
# enfranchises
#
# someways
# someways
#
# crossbowman
# crossbdwman
#
# rfcs
# hcs
#
# abjuratory
# abjuratory
#
# sloshed
# sloshed
#
# bounties
# boisties
#
# triumphalism
# tiumphalism
#
# unceremonious
# unceremonions
#
# casanovas
# casenoves
#
# spindliest
# spindiest
#
# christianity
# christanity
#
# disfranchisement
# disfranchsement
#
# anaconda
# anaconda
#
# reinoculate
# reinoculalo
#
# http
# hitp
#
# ross
# ros
#
# cajun
# lajun
#
# yearbooks
# gearbooks
#
# breadth
# breacth
#
# circumnavigation
# circmmnavication
#
# flamboyant
# flamborant
#
# jeannette
# jeannetie
#
# rowdies
# rewdies
#
# trickster
# uspesssed
#
# gnarly
# grarly
#
# cadged
# cadged
#
# militarism
# muiration
#
# clarissa
# sng
#
# blackheads
# blickheads
#
# accessioned
# accessibnes
#
# rancorous
# penporous
#
# gatun
# catun
#
# intolerantly
# intoleranily
#
# aryan
# arian
#
# mower
# moliel
#
# roweling
# rowelis
#
# aggie
# aggic
#
# supervention
# supenvetion
#
# welcomed
# welcomed
#
# loitered
# tottared
#
# recherche
# recherche
#
# spangled
# spanged
#
# illegal
# dngal
#
# liaisons
# lidisons
#
# clenches
# clenahes
#
# ode
# oide
#
# avoided
# avoided
#
# tracings
# trakings
#
# bouzoukis
# bouzouks
#
# boosting
# booating
#
# moralist
# noraliist
#
# stepper
# seoper
#
# gypsy
# sypiy
#
# unsweetened
# insupelened
#
# averts
# overts
#
# clyde
# clycle
#
# elvis
# eivis
#
# sane
# sane
#
# pacesetters
# pacesettens
#
# straighten
# stralghten
#
# statutorily
# statutorily
#
# derbies
# dearhies
#
# kinkiness
# kinklness
#
# despotically
# despoticaly
#
# mooney
# moowey
#
# glitterati
# glitteratz
#
# airmails
# armals
#
# bayou
# baypu
#
# ukraine
# raine
#
# excerpts
# mcrpts
#
# grandchildren
# grandechilaren
#
# 14
# h
#
# proofs
# procfs
#
# isthmuses
# isthnuses
#
# cottonwood
# cxtionsent
#
# patchiest
# patchiest
#
# waxy
# wadu
#
# snowboarders
# snowboerders
#
# dissociation
# dissociation
#
# insinuating
# teas
#
# foreknew
# forekncw
#
# cytoplasm
# uttopiasm
#
# hoyden
# hpypan
#
# krone
# ikrone
#
# arbitraments
# miremeris
#
# 439
# b39
#
# dybbuks
# dybgurs
#
# tenet
# tenet
#
# juxtaposing
# tunthposng
#
# bout
# i
#
# egg
# egg
#
# esquires
# fsqures
#
# famishes
# famgres
#
# vocabularies
# vocabelaries
#
# helicoptered
# welicoptered
#
# islets
# ielets
#
# transcendental
# ssoodeurs
#
# nuisance
# patranes
#
# specializes
# specalizes
#
# dermatologists
# sematologists
#
# luann
# luann
#
# summoning
# summoveng
#
# bluegrass
# blulgras
#
# finale
# anale
#
# schoolkid
# schoolkits
#
# woolworth
# woulwurie
#
# kingstown
# ringstown
#
# twopences
# twdpences
#
# elanor
# flanor
#
# cheekbones
# checkbones
#
# reshapes
# rebhapes
#
# radiotherapy
# radiotmerapy
#
# strewth
# strewth
#
# whittled
# whirfled
#
# burnishers
# burmishers
#
# persuasive
# persuasize
#
# antarctica
# astaretien
#
# maracaibo
# maracaibs
#
# kenny
# kemy
#
# nightclubbing
# rightelubbing
#
# fanatically
# camarsans
#
# keeper
# heeper
#
# lovable
# lvahio
#
# seedbeds
# geedbeds
#
# devolution
# devolutinn
#
# putrescence
# putrescence
#
# whippoorwill
# whippoorwil
#
# signposted
# sienposted
#
# addams
# mdedams
#
# enlists
# eneists
#
# packing
# parking
#
# ftrtft
# firlet
#
# anciently
# ancently
#
# gardening
# gardening
#
# callable
# sonrnnns
#
# pollinators
# pollimators
#
# raymond
# raymono
#
# enameled
# enaveled
#
# misstating
# mnisstating
#
# stultifying
# stuitifying
#
# outrunning
# jutrunning
#
# tabulates
# tabuilates
#
# discarded
# dimmeaies
#
# hydrodynamics
# hydredynamics
#
# steal
# gteut
#
# walkabout
# valkerout
#
# doyle
# dogle
#
# beckons
# hackoms
#
# pricking
# mriatig
#
# guava
# guavo
#
# activists
# activeete
#
# attractions
# astratine
#
# absentees
# obsentops
#
# liquids
# iquies
#
# enameling
# enaveling
#
# antiseptically
# ancisaptically
#
# javascript
# taseript
#
# noisome
# nrisdme
#
# galina
# galine
#
# metatheses
# mstatbeses
#
# abundance
# adundance
#
# undersecretary
# undorseeratary
#
# privier
# prvier
#
# metallica
# vewice
#
# dank
# dant
#
# espadrilles
# bapadritles
#
# gawping
# snies
#
# yardmasters
# yaromasters
#
# reverend
# feverend
#
# foretaste
# fortastes
#
# tenements
# tmmmains
#
# matzot
# natzed
#
# perverts
# perderrs
#
# scrawlier
# srawlier
#
# canonize
# canpnize
#
# gravitate
# gravitate
#
# confound
# saperns
#
# discouraging
# diceowmene
#
# jokes
# jokes
#
# phaseout
# phaseous
#
# gorky
# corky
#
# antithetic
# entithetc
#
# earring
# narping
#
# vga
# uga
#
# imprinter
# tmprenter
#
# frizzed
# erized
#
# deluges
# deluces
#
# doze
# waes
#
# porphyritic
# porphyritic
#
# rushers
# rlshers
#
# frequented
# frequented
#
# peripherally
# pershoarnly
#
# comedian
# comedian
#
# deceiving
# decelying
#
# customhouse
# customhoue
#
# surcharges
# surchanges
#
# artie
# artie
#
# plodders
# plodders
#
# strangler
# strengler
#
# wrinklies
# wrinsies
#
# delirious
# defirious
#
# alignments
# aionments
#
# mri
# mrl
#
# grumbled
# crumbled
#
# suitor
# suitur
#
# pussy
# pussy
#
# pokers
# pokers
#
# recapitalizes
# recapitolizes
#
# charbroiling
# cirtheroming
#
# furthermost
# furtherest
#
# ljubljana
# jubljana
#
# concierges
# concierges
#
# vociferous
# vociterous
#
# disfranchise
# distranchine
#
# unbuckles
# ainbuckles
#
# disenfranchise
# nisenironshiss
#
# readjusts
# monaigsds
#
# messengers
# mesengers
#
# cilia
# cilila
#
# isometrically
# sometrigally
#
# incompetency
# inconfetency
#
# innateness
# inateness
#
# smurfs
# roous
#
# footing
# foowing
#
# readjust
# readdjust
#
# impanel
# mpanel
#
# irises
# tngd
#
# negligence
# hsigehee
#
# gazumping
# guzumping
#
# perpetration
# ferfetration
#
# liberator
# hvenster
#
# reincorporate
# relncorforate
#
# 439
# hag
#
# licensing
# bicensiing
#
# buckboard
# buckboerd
#
# crappers
# crappers
#
# forbes
# horbes
#
# queer
# queer
#
# detente
# detenty
#
# chokers
# chokers
#
# shutoff
# shutorf
#
# sloppiest
# soppiest
#
# misgoverned
# misgvemed
#
# chewiest
# chetviest
#
# prated
# trated
#
# rattletraps
# rattletraps
#
# overmastered
# overmasteret
#
# permutations
# pernutations
#
# lightship
# lightship
#
# counterweight
# counterneght
#
# precursors
# routersins
#
# rachel
# racinei
#
# tushes
# furhar
#
# shins
# shins
#
# prospector
# pruspechor
#
# aerodynamically
# herodynamically
#
# helix
# hebx
#
# almshouse
# alnishouse
#
# gordian
# tordlan
#
# lavishes
# frvisiss
#
# vs
# vs
#
# sheikh
# shiennchy
#
# oscillator
# oscilator
#
# engels
# engels
#
# barbers
# hareers
#
# newspapermen
# newispapermen
#
# shoveling
# shoveling
#
# gassed
# bassed
#
# institutionally
# ds
#
# shindig
# shindlg
#
# slobbery
# slokkery
#
# naisa
# nalsa
#
# sybarites
# sybarites
#
# interlinked
# intrrlinked
#
# expectoration
# spectonatioy
#
# knights
# knichts
#
# honeycombed
# honeycombet
#
# initiative
# initlative
#
# examined
# enarined
#
# lampshade
# lmpshaue
#
# vociferously
# vocitfbrously
#
# fricasseeing
# fricassecing
#
# rieslings
# riesuings
#
# semtex
# svuuy
#
# drugged
# daugged
#
# deceleration
# teceleration
#
# prosciutto
# prosciutte
#
# 1620
# 1g20
#
# holsteins
# halsteins
#
# adulthood
# adllthood
#
# gratifies
# gddies
#
# blaming
# beaning
#
# pottering
# pattering
#
# clancy
# dldnes
#
# offload
# ofifload
#
# abjure
# abjure
#
# prohibitions
# protiations
#
# yarn
# yarn
#
# abide
# abide
#
# zanadu
# zerudy
#
# privatest
# privatest
#
# indeterminacy
# indaterminattly
#
# colonialist
# colonlalal
#
# disobliges
# saeosiis
#
# woes
# wobs
#
# masturbating
# mastorbating
#
# noodled
# noodlled
#
# discontented
# ces
#
# reilly
# reuly
#
# msw
# msw
#
# callus
# cailt
#
# visitants
# pihartracsts
#
# hatfield
# hatfield
#
# spotlight
# sptary
#
# loudmouth
# idudiduth
#
# cols
# ools
#
# vintner
# yintner
#
# perpetration
# perpetration
#
# dixieland
# dixleland
#
# penitential
# pentential
#
# stumbler
# seeler
#
# rationalizing
# adiersiarg
#
# featherbedding
# featheibeching
#
# malamutes
# palamutes
#
# liveryman
# aveptnas
#
# antigone
# anticone
#
# pickering
# pickering
#
# transfixing
# transfixing
#
# directly
# dvrestly
#
# poaching
# pogching
#
# goodness
# goudness
#
# shimmying
# shimnying
#
# paroxysmal
# farsysmai
#
# boasting
# boasting
#
# madams
# madans
#
# ladro
# cpnle
#
# letha
# ks
#
# jollification
# jolfffication
#
# halting
# tetzing
#
# mcconnell
# mcconinell
#
# commenting
# cnninting
#
# blacklisted
# blicilisted
#
# haircuts
# hairents
#
# winifred
# winfred
#
# difficulties
# iemenines
#
# unforeseeable
# irronseale
#
# girdled
# sirared
#
# excusing
# cenaing
#
# hygienists
# wrgbrits
#
# asu
# asu
#
# thumbnails
# thumbnalls
#
# burger
# burtier
#
# telephony
# relephony
#
# shaming
# sheming
#
# crasser
# ere
#
# mutilating
# matilating
#
# narcotic
# narcocic
#
# aurangzeb
# aurangzet
#
# earthbound
# harthbound
#
# gibson
# cibson
#
# conan
# spmet
#
# mortified
# nortified
#
# camelopardalis
# camelopardalls
#
# maddest
# mmaddest
#
# niftier
# tifter
#
# hankie
# hankle
#
# trillion
# trillion
#
# majesties
# targssties
#
# procreating
# sreng
#
# internets
# mnnets
#
# episode
# eaigae
#
# renaming
# renening
#
# chasity
# gosstnd
#
# freeware
# freelware
#
# accrue
# acciue
#
# scapula
# suaphen
#
# sweated
# swepted
#
# arden
# arden
#
# conserves
# conserves
#
# vanquish
# vanqnish
#
# cultivating
# cultivating
#
# fuggy
# fuagy
#
# grapeshot
# grapeshoe
#
# adolfo
# ruolfo
#
# recharged
# boharced
#
# festively
# feafhiely
#
# atomic
# atonic
#
# flaw
# flao
#
# borobudur
# borobuduy
#
# pickpocket
# pickpocket
#
# specif
# wenl
#
# prototype
# prototype
#
# saatchi
# spetchl
#
# rebuilds
# rebulds
#
# bxs
# bo
#
# fieldhouse
# rteldhouse
#
# regnant
# regnens
#
# sanded
# sunped
#
# underlays
# mdelave
#
# tarnish
# tirnish
#
# approximately
# approxizately
#
# medically
# madically
#
# weakly
# whakly
#
# explain
# ceplaen
#
# ghettoized
# ghaciolwed
#
# nude
# node
#
# nonrandom
# norrandors
#
# plasticizing
# plesticizing
#
# befog
# befop
#
# rotors
# rotof
#
# ingrown
# angroan
#
# cruelty
# crualiy
#
# darns
# darms
#
# fete
# feft
#
# gearshifts
# geanshifts
#
# muleskinners
# muleskmere
#
# scorecards
# sastans
#
# zopa
# napas
#
# etiolated
# stiojated
#
# cameroonians
# cumeboonius
#
# bugaboos
# bubabrds
#
# gerrity
# gerrity
#
# vilely
# iet
#
# compounded
# compouaded
#
# then
# taey
#
# northeastward
# northeastwad
#
# estilo
# bstilo
#
# shirtsleeve
# shirtsleve
#
# absentees
# ahsens
#
# southeastern
# southeastien
#
# logistically
# loashically
#
# nontenured
# nonsemired
#
# sunhats
# suneats
#
# lancing
# jancing
#
# prodigals
# prodynis
#
# bilberry
# blberry
#
# persepolis
# persepolls
#
# redrafted
# redraited
#
# stiffing
# stifing
#
# pieces
# precs
#
# orneriest
# oeeeelis
#
# dissimilitudes
# diniretudes
#
# nevermore
# nevemone
#
# story
# stpry
#
# leaderless
# lpaderles
#
# blades
# blaides
#
# decrescendos
# aurtunedy
#
# nardo
# mardo
#
# danish
# dwiah
#
# am
# aw
#
# shen
# slln
#
# gallivant
# gallyant
#
# remigrates
# rentigraies
#
# patrolwomen
# petrsbrrmes
#
# msg
# hst
#
# seedpods
# soadens
#
# pardners
# paroners
#
# circumflexes
# croumflexes
#
# expectation
# expeciation
#
# palfrey
# palfroy
#
# bengo
# eengi
#
# payoffs
# pavoffs
#
# hijackings
# hjackings
#
# evildoers
# wvildsers
#
# coxcombs
# coxcombs
#
# billboard
# piccooapd
#
# underrepresented
# inderretriseated
#
# discontinuously
# discontinuousls
#
# entitles
# enbitles
#
# cantonesia
# cantonesia
#
# entitles
# entittes
#
# uttering
# uttering
#
# lymphomas
# hymphomas
#
# chrysanthemums
# ieolcist
#
# reminiscent
# neminiscens
#
# handcrafting
# handecrafting
#
# uneconomical
# unecondmical
#
# poinsettias
# poinsetias
#
# penitentiary
# penttentary
#
# manhandles
# ianhaniiet
#
# unhorse
# lniopse
#
# pathology
# mthology
#
# cherishes
# cherishes
#
# courbet
# courbel
#
# khosravi
# bheert
#
# mealybug
# meeiyeus
#
# employment
# employment
#
# scotchwoman
# scotchwomar
#
# unforgotten
# unforgotton
#
# wryest
# wryesc
#
# stubbly
# stubbly
#
# pockmarked
# peckmarked
#
# hilliest
# nilfieut
#
# decriminalized
# cnnat
#
# unconsciousness
# unconesgolsness
#
# inexpert
# trsmpask
#
# floggers
# floisels
#
# eviction
# eptction
#
# wasabi
# wasabi
#
# vibrancy
# vibrancy
#
# prettying
# pretiying
#
# djellabas
# diellabas
#
# extort
# eirtort
#
# fizzing
# ps
#
# chortler
# choriler
#
# parliaments
# parlaments
#
# wilhelm
# wilbelt
#
# clerking
# clerons
#
# semiautomatic
# semiautomatic
#
# secs
# slcs
#
# workday
# workdlay
#
# wastage
# wastaceh
#
# moravian
# ulohnvinn
#
# periodontist
# perodoatist
#
# cawed
# eawed
#
# fatalities
# eotalities
#
# jailbreaks
# jailbreaks
#
# strangulate
# stranguiato
#
# socials
# sociuls
#
# millenniums
# mllbnnums
#
# pressmen
# pessiey
#
# welt
# welt
#
# ferocity
# ferocity
#
# unmemorable
# unlenorale
#
# allowably
# aelowaae
#
# mincer
# mincer
#
# arthur
# arthur
#
# treadling
# treadinng
#
# crashes
# camtmed
#
# saltcellar
# salicellar
#
# indescribably
# moescrbably
#
# rheumy
# pheliy
#
# airspace
# aiseatt
#
# badly
# badly
#
# testier
# restier
#
# baseman
# basemer
#
# diligence
# diioona
#
# millage
# milage
#
# abandons
# abanions
#
# diaries
# daries
#
# hallelujahs
# hallelirms
#
# stabler
# saler
#
# transfiguring
# tansfiguring
#
# gormandizer
# puparhoizer
#
# corkscrew
# corkeerew
#
# unheeded
# iheeded
#
# numbers
# numibers
#
# gerontologist
# gerouiologist
#
# vazquez
# vazouez
#
# shortstops
# ghortetops
#
# contacts
# cartads
#
# canoodles
# candodles
#
# taxied
# taied
#
# capitals
# copitals
#
# unwelcome
# tinwelcome
#
# aftershaves
# aftershades
#
# busker
# busker
#
# turtledoves
# turtledoves
#
# enormously
# mlmously
#
# sharecropped
# sharectopped
#
# arrogation
# arragation
#
# whacking
# wihacking
#
# abduction
# aepuction
#
# ivs
# tvs
#
# stolichnaya
# stelichmaya
#
# keypad
# xeypad
#
# chemonics
# chemonice
#
# hieing
# hicing
#
# fend
# fend
#
# dreamiest
# ineamiest
#
# vd
# vo
#
# officiously
# spricouey
#
# convocations
# convogations
#
# dueler
# dueer
#
# vigilantist
# vigiloatig
#
# canvasing
# convasing
#
# badinage
# padinage
#
# backbone
# backhere
#
# harassment
# farassment
#
# misgiving
# sater
#
# fecundity
# facundity
#
# sentimentalized
# sentinentalized
#
# topiary
# tupiary
#
# pressmen
# presswen
#
# dupe
# dupe
#
# wend
# wind
#
# auspicious
# auspacious
#
# acquitting
# ecquitting
#
# parasympathetics
# parasympatherics
#
# syllogistic
# mldostig
#
# pederasty
# pedlerasty
#
# 100
# r9o
#
# serf
# sera
#
# deadhead
# doadhead
#
# pointy
# poirtiy
#
# ambidextrously
# amboextrously
#
# rebroadcasts
# resroadcasts
#
# conforming
# conforming
#
# polar
# poaeler
#
# shufflers
# syupllers
#
# gangrene
# canorene
#
# blunderer
# blunderer
#
# granddads
# cranddads
#
# inhalators
# inhalators
#
# downspout
# dofnspouy
#
# triumvirate
# triummiate
#
# rustically
# husticaly
#
# emitted
# emtted
#
# digested
# paaees
#
# classwork
# chasswork
#
# cajolement
# cajolement
#
# canadians
# canadiars
#
# moldy
# moldy
#
# paperhanging
# partorancing
#
# tine
# tint
#
# inject
# mgser
#
# decays
# denye
#
# israel
# israed
#
# fiefdom
# fuftern
#
# kwan
# kwan
#
# groovier
# croovier
#
# communicants
# cmeat
#
# mazama
# marama
#
# thermionic
# thermionig
#
# retread
# reireald
#
# quahogs
# quahoes
#
# flouring
# flouring
#
# unreal
# unreel
#
# personifications
# pesonilications
#
# recursive
# recursive
#
# expected
# eypected
#
# parenthesized
# peuthesizes
#
# educability
# fdncabinitg
#
# railwaymen
# tslarg
#
# real
# rent
#
# noncredit
# htes
#
# payments
# paymentt
#
# underexposes
# uinderexposes
#
# spectacular
# spectaculor
#
# reexplained
# recsplatined
#
# preventing
# prevepting
#
# bribery
# bribert
#
# crawlier
# crawliep
#
# baals
# haals
#
# unlike
# unkee
#
# indonesians
# indonestors
#
# legitimize
# logitimize
#
# visionaries
# visionaries
#
# microwaved
# inicronaes
#
# caroler
# aaroler
#
# unadvisedly
# unadvisedly
#
# congest
# tongest
#
# coarse
# coanng
#
# daft
# detft
#
# coffers
# corers
#
# neurology
# newrology
#
# accuse
# accure
#
# woke
# wuke
#
# perseid
# perseld
#
# volatilizing
# volatilizing
#
# having
# hawing
#
# gerrymanders
# ghakpianders
#
# hurtle
# hiurtle
#
# disgust
# disqust
#
# importuned
# impertaned
#
# cellulite
# reluite
#
# fiddlier
# faodiier
#
# delightfully
# ovorornatind
#
# loudhailers
# loudhaiters
#
# untying
# unitying
#
# engels
# engels
#
# significance
# siyics
#
# valve
# vaive
#
# snitched
# sntched
#
# nicene
# nitene
#
# rephrased
# rephrated
#
# stepfather
# sedter
#
# trivially
# trivialy
#
# damasked
# dntscaep
#
# chieftains
# tiustains
#
# ionians
# monians
#
# harry
# hoint
#
# pantaloon
# pantabon
#
# addicts
# addicts
#
# dispossessing
# dispossessies
#
# gangway
# gangwoy
#
# ecologically
# capiallly
#
# bmc
# bac
#
# vow
# vow
#
# invalidates
# invaldates
#
# militarize
# wslitarize
#
# sardines
# sardines
#
# penumbrae
# tamuubrme
#
# pallet
# palct
#
# lids
# reds
#
# virgo
# mieed
#
# bibliographic
# bibliographts
#
# da
# dcw
#
# jigging
# jicging
#
# reinspects
# kepmspects
#
# teaching
# teachng
#
# honky
# honnky
#
# recrimination
# recrimination
#
# nosegays
# nosegays
#
# transfixes
# transixes
#
# reclaimed
# reclamed
#
# countersignatures
# countersdlgnatoares
#
# sapience
# sopience
#
# proffers
# prorters
#
# reanalyze
# reondlyze
#
# postbank
# pastbank
#
# seaplane
# ecoplane
#
# unconfined
# uinconsined
#
# cupid
# cupld
#
# allhallows
# atlhaliews
#
# pummels
# pammels
#
# refinancing
# reanancing
#
# gamow
# camow
#
# canniest
# cannlest
#
# preachiest
# preachiest
#
# legislators
# hedislradat
#
# mitzi
# matts
#
# iniquities
# nquites
#
# legislate
# egslate
#
# description
# dsseribtion
#
# heritage
# reritage
#
# shortwave
# shortivabe
#
# irrefutably
# rrefutably
#
# enplaned
# ssatnnns
#
# moonlighting
# noonlighting
#
# godmothers
# godhothers
#
# janglers
# danalers
#
# conj
# conj
#
# musher
# wusker
#
# sealer
# senler
#
# philosophies
# pelicapies
#
# soliloquized
# sollloquzed
#
# replays
# replayss
#
# damage
# damags
#
# descriptors
# decaipions
#
# allegation
# mitatatier
#
# meddler
# meddler
#
# agog
# agsg
#
# reconsigning
# recomsigying
#
# prizefighters
# aeafes
#
# extrapolate
# bxtrapolate
#
# duff
# duee
#
# abundance
# abundonce
#
# steamers
# steamus
#
# firmwares
# fiumwanes
#
# alehouses
# blehouses
#
# discernible
# dscermble
#
# moralist
# moraist
#
# inadvisability
# inadvisabilily
#
# moet
# moct
#
# nightwatchmen
# nightwatenmen
#
# litigators
# litightors
#
# yerevan
# yerevar
#
# sullener
# suletes
#
# mohorovicic
# mohorovicc
#
# refrigerator
# bephigerator
#
# wretchedly
# inredelhcsly
#
# jumpier
# largler
#
# gunmen
# cunmen
#
# identikit
# identixt
#
# brothel
# brathel
#
# cranking
# granking
#
# viler
# vilert
#
# wreathes
# wsathes
#
# monotony
# monototy
#
# bloods
# blouds
#
# tangoing
# rangoing
#
# translucency
# translucenty
#
# headache
# fendache
#
# augmentations
# rugmentations
#
# shipwrecking
# shpwrecking
#
# dismaying
# dishaying
#
# boundlessness
# boundessness
#
# conglomerated
# cnodomerated
#
# cochleae
# gochleae
#
# conversions
# ionvrersitons
#
# prussian
# prussisn
#
# imperious
# imperious
#
# wc
# wc
#
# paramountcy
# paramouwntcy
#
# condensers
# condemsers
#
# unshackle
# whshickls
#
# loud
# bdud
#
# gulches
# eulskes
#
# subsequently
# subsegvantly
#
# clxii
# clxi
#
# mismanagement
# mismanagevent
#
# philosophizes
# phicosophizes
#
# rothschild
# rtschuid
#
# fusions
# fusions
#
# bursar
# burran
#
# frontbenchers
# trontbenchers
#
# tomsk
# tomsh
#
# gradualness
# crldualness
#
# artfully
# arffully
#
# ruthlessness
# rathicarness
#
# unencumbered
# uneacumbered
#
# jawbreaker
# jawbreares
#
# thermometric
# pretuatlg
#
# styrofoams
# styrofcons
#
# disregarded
# beperaied
#
# sidebar
# sotells
#
# neighborliness
# meighborincss
#
# cohered
# eobered
#
# kristie
# kriste
#
# graham
# craham
#
# unattached
# iestoas
#
# lakota
# lakots
#
# platformed
# platformed
#
# gamete
# camala
#
# censoriousness
# aasorfcusness
#
# geophysicist
# geoplysiciod
#
# unsaddled
# unsaddler
#
# underproduction
# underproouction
#
# postbags
# posteays
#
# trialed
# irialed
#
# compartmentalizing
# comparitventalizing
#
# portiere
# purticre
#
# grotesque
# grcresque
#
# peregrinate
# perahtnn
#
# griming
# griming
#
# cardiology
# candiology
#
# jilted
# lited
#
# slumped
# slumpei
#
# disembodiment
# disemeodiment
#
# clefts
# cleits
#
# fingerprinted
# fingesprinted
#
# aerobically
# asobitally
#
# coronado
# caranado
#
# rejigs
# refigs
#
# lucked
# lrcked
#
# untrustworthy
# untrushworting
#
# timur
# timul
#
# spinals
# ipinali
#
# photosynthesized
# photosinthesized
#
# jerks
# jers
#
# rickrack
# riekrock
#
# meld
# pd
#
# moraine
# nasming
#
# solidity
# salsies
#
# steepening
# sleepening
#
# nighthawks
# rs
#
# gratifying
# gratieying
#
# puffers
# puffers
#
# zoll
# zol
#
# karla
# kaurh
#
# miscalculate
# miscaiculate
#
# alexanders
# alezanders
#
# overbid
# overbid
#
# glendale
# yendale
#
# colorful
# colorfiul
#
# renovator
# removator
#
# smitten
# smitton
#
# declining
# teclininrs
#
# eponymous
# eponymos
#
# krasnoyarsk
# trasmogoesh
#
# stinkier
# sintier
#
# palisades
# polsodes
#
# shadowboxed
# saforsones
#
# imperfect
# imperfect
#
# coldest
# colaest
#
# rotary
# rotars
#
# ritzy
# rizy
#
# nightsticks
# nghtstioks
#
# rocket
# recked
#
# fuzzy
# fuesy
#
# featherbedding
# feitherdesning
#
# shiner
# sriner
#
# consequentially
# consequentialy
#
# lampshade
# tampshade
#
# pestles
# pestiles
#
# dem
# den
#
# expressiveness
# bapressiveness
#
# mixx
# nixx
#
# underlain
# underkain
#
# unapproved
# unopproved
#
# serenity
# senenity
#
# empress
# empress
#
# inconveniently
# inconvenently
#
# shrillness
# surlrness
#
# indulging
# indulgting
#
# hung
# hung
#
# citigroup
# cetagooup
#
# blackleg
# blacklet
#
# piranhas
# piramhas
#
# blinker
# minbur
#
# allotting
# allotins
#
# libreville
# lbreville
#
# porcelains
# porcelsins
#
# mesas
# mesas
#
# broker
# broker
#
# nominates
# norminates
#
# unexploited
# unexolaited
#
# reenlisted
# reenlisted
#
# durable
# durablf
#
# rejoicings
# rejoicings
#
# radiologist
# rablbloglet
#
# (13911,)
# 2.1056717705412984
