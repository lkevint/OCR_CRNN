# %%
# Import PyTorch
import torch
from torch import nn

# Import torchvision 
import torchvision
from torchvision.transforms import v2#, ToTensor

# Import DataLoader
from torch.utils.data import DataLoader

# Setup device
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## Preparing Data

# %%
from datasets import load_dataset
train_dataset = load_dataset('priyank-m/MJSynth_text_recognition', split='train')
test_dataset = load_dataset('priyank-m/MJSynth_text_recognition', split='test')

# %%
import PIL
import cv2

# Process images
def process_image(pil_img):
    # Convert PIL Image to grayscale
    img = pil_img.convert('L')

    # Convert PIL Image to np array
    img = np.array(img)

    # Resize image to 32 height and/or 128 width if larger
    w, h = img.shape
    if w > 128:
        img = cv2.resize(img, (128, h), interpolation=cv2.INTER_AREA)
        w = 128

    if h > 32:
        img = cv2.resize(img, (w, 32), interpolation=cv2.INTER_AREA)
        h = 32

    # Add padding
    if h < 32 or w < 128:
        add_zeros_height = np.ones((32 - h, min(128, w))) * 255  # Pad height if needed
        add_zeros_width = np.ones((32, 128 - w)) * 255  # Pad width if needed

        img = np.concatenate((img, add_zeros_height), axis=0) if h < 32 else img
        img = np.concatenate((img, add_zeros_width), axis=1) if w < 128 else img

    # Normalize image
    img = img/255.0
    img = np.expand_dims(img, axis=2)
    return img

#Process/split dataset
training_img = []
training_txt = []

train_input_length = []
train_label_length = []

orig_txt = []
max_label_len = 0
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[69], line 2
#       1 import PIL
# ----> 2 import cv2
#       4 # Process images
#       5 def process_image(pil_img):
#       6     # Convert PIL Image to grayscale
#
# ModuleNotFoundError: No module named 'cv2'

# %%
for i, item in enumerate(dataset):
    if i%100 = 0
    print(i)
    #Process image
    img = process_image(item['image'])

    #Extract text
    txt = item['label']

    #Update maximum label length
    max_label_len = max(max_label_len, len(txt))

    #Split data into validation/training sets
    orig_txt.append(txt)
    training_img.append(img)
    training_txt.append(encode_to_labels(txt))
    train_label_length.append(len(txt))
    train_input_length.append(31)

    #Limit # processed images
    if i == 499999:
        break

print(f"Processed {len(training_img)} training images.")

# %%
BATCH_SIZE = 32

# Turn datasets into iterables (batches)
train_dataloader = DataLoader(train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True # shuffle data every epoch
)

test_dataloader = DataLoader(test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False # don't necessarily have to shuffle the testing data
)

# Check out what's inside the training dataloader
train_features_batch, train_labels_batch = next(iter(train_dataloader))
train_features_batch.shape, train_labels_batch.shape
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[61], line 15
#       9 test_dataloader = DataLoader(test_dataset,
#      10     batch_size=BATCH_SIZE,
#      11     shuffle=False # don't necessarily have to shuffle the testing data
#      12 )
#      14 # Check out what's inside the training dataloader
# ---> 15 train_features_batch, train_labels_batch = next(iter(train_dataloader))
#      16 train_features_batch.shape, train_labels_batch.shape
#
# File C:\ProgramData\miniconda3\Lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
# ...

# %%
import CRNN
model_2 = CRNN(input_shape=1, 
    hidden_units=10, 
    output_shape=len(class_names)).to(device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 4
#       1 import CRNN
#       2 model_2 = CRNN(input_shape=1,
#       3     hidden_units=10,
# ----> 4     output_shape=len(class_names)).to(device)
#
# NameError: name 'class_names' is not defined
